# %% [markdown]
# ![Img](https://app.theheadstarter.com/static/hs-logo-opengraph.png)
#
# # Headstarter Financial Analysis & Automation with LLMs Project

# %% [markdown]
# # Install Libraries

# %%
! pip install yfinance langchain_pinecone openai python-dotenv langchain-community sentence_transformers
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.50)
# Collecting langchain_pinecone
#   Downloading langchain_pinecone-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.5)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Collecting aiohttp<3.10,>=3.9.5 (from langchain_pinecone)
#   Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in /usr/local/lib/python3.10/dist-packages (from langchain_pinecone) (0.3.21)
# Collecting pinecone-client<6.0.0,>=5.0.0 (from langchain_pinecone)
#   Downloading pinecone_client-5.0.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.28.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.8.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.36)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting langchain<0.4.0,>=0.3.10 (from langchain-community)
#   Downloading langchain-0.3.10-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core<0.4,>=0.3 (from langchain_pinecone)
#   Downloading langchain_core-0.3.22-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.1.147)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.6.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.46.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.26.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (11.0.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (1.18.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (4.0.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (24.2)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.10->langchain-community) (0.3.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain_pinecone) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Collecting pinecone-plugin-inference<2.0.0,>=1.0.3 (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone)
#   Downloading pinecone_plugin_inference-1.1.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone) (2.2.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.4.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain_pinecone) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp<3.10,>=3.9.5->langchain_pinecone) (0.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Downloading langchain_pinecone-0.2.0-py3-none-any.whl (11 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading langchain_community-0.3.10-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 36.5 MB/s eta 0:00:00
# Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 54.9 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langchain-0.3.10-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 41.3 MB/s eta 0:00:00
# Downloading langchain_core-0.3.22-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.7/409.7 kB 27.4 MB/s eta 0:00:00
# Downloading pinecone_client-5.0.1-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.8/244.8 kB 18.1 MB/s eta 0:00:00
# Downloading pydantic_settings-2.6.1-py3-none-any.whl (28 kB)
# Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.2 MB/s eta 0:00:00
# Downloading pinecone_plugin_inference-1.1.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 5.4 MB/s eta 0:00:00
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, pinecone-plugin-interface, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pinecone-plugin-inference, pydantic-settings, pinecone-client, dataclasses-json, aiohttp, langchain-core, langchain_pinecone, langchain, langchain-community
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.9
#     Uninstalling aiohttp-3.11.9:
#       Successfully uninstalled aiohttp-3.11.9
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.21
#     Uninstalling langchain-core-0.3.21:
#       Successfully uninstalled langchain-core-0.3.21
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.9
#     Uninstalling langchain-0.3.9:
#       Successfully uninstalled langchain-0.3.9
# Successfully installed aiohttp-3.9.5 dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-0.3.10 langchain-community-0.3.10 langchain-core-0.3.22 langchain_pinecone-0.2.0 marshmallow-3.23.1 mypy-extensions-1.0.0 pinecone-client-5.0.1 pinecone-plugin-inference-1.1.0 pinecone-plugin-interface-0.0.7 pydantic-settings-2.6.1 python-dotenv-1.0.1 typing-inspect-0.9.0

# %%
from langchain_pinecone import PineconeVectorStore
from openai import OpenAI
import dotenv
import json
import yfinance as yf
import concurrent.futures
from langchain_community.embeddings import HuggingFaceEmbeddings
from google.colab import userdata
from langchain.schema import Document
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from pinecone import Pinecone
import numpy as np
import requests
import os

# %%
def get_stock_info(symbol: str) -> dict:
    """
    Retrieves and formats detailed information about a stock from Yahoo Finance.

    Args:
        symbol (str): The stock ticker symbol to look up.

    Returns:
        dict: A dictionary containing detailed stock information, including ticker, name,
              business summary, city, state, country, industry, and sector.
    """
    data = yf.Ticker(symbol)
    stock_info = data.info

    properties = {
        "Ticker": stock_info.get('symbol', 'N/A'),
        'Name': stock_info.get('longName', 'N/A'),
        'Business Summary': stock_info.get('longBusinessSummary', 'N/A'),
        'City': stock_info.get('city', 'N/A'),
        'State': stock_info.get('state', 'N/A'),
        'Country': stock_info.get('country', 'N/A'),
        'Industry': stock_info.get('industry', 'N/A'),
        'Sector': stock_info.get('sector', 'N/A'),
        'Market Cap': stock_info.get('marketCap', 0),
        'Volume': stock_info.get('volume', 0),
        '52_Week_Change': stock_info.get('52WeekChnage', 0),
        'Revenue_Growth': stock_info.get('revenueGrowth', 0),
        'EBIDTA_Margins': stock_info.get('ebitdaMargins', 0),
        'Gross_Margins': stock_info.get('grossMargins', 0),
        'Earnings_Growth': stock_info.get('earningsGrowth', 0),
        'Shares_Short': stock_info.get('sharesShort', 0),
        'Beta': stock_info.get('beta', 0),
        'website': stock_info.get('website', 'N/A'),
    }

    return properties

# %%
data = yf.Ticker("TSLA")
stock_info = data.info

for key, value in stock_info.items():
    print(f"{key}: {value}")
# Out:
# dict_keys(['address1', 'city', 'state', 'zip', 'country', 'phone', 'website', 'industry', 'industryKey', 'industryDisp', 'sector', 'sectorKey', 'sectorDisp', 'longBusinessSummary', 'fullTimeEmployees', 'companyOfficers', 'auditRisk', 'boardRisk', 'compensationRisk', 'shareHolderRightsRisk', 'overallRisk', 'governanceEpochDate', 'compensationAsOfEpochDate', 'maxAge', 'priceHint', 'previousClose', 'open', 'dayLow', 'dayHigh', 'regularMarketPreviousClose', 'regularMarketOpen', 'regularMarketDayLow', 'regularMarketDayHigh', 'beta', 'trailingPE', 'forwardPE', 'volume', 'regularMarketVolume', 'averageVolume', 'averageVolume10days', 'averageDailyVolume10Day', 'bid', 'ask', 'bidSize', 'askSize', 'marketCap', 'fiftyTwoWeekLow', 'fiftyTwoWeekHigh', 'priceToSalesTrailing12Months', 'fiftyDayAverage', 'twoHundredDayAverage', 'currency', 'enterpriseValue', 'profitMargins', 'floatShares', 'sharesOutstanding', 'sharesShort', 'sharesShortPriorMonth', 'sharesShortPreviousMonthDate', 'dateShortInterest', 'sharesPercentSharesOut', 'heldPercentInsiders', 'heldPercentInstitutions', 'shortRatio', 'shortPercentOfFloat', 'impliedSharesOutstanding', 'bookValue', 'priceToBook', 'lastFiscalYearEnd', 'nextFiscalYearEnd', 'mostRecentQuarter', 'earningsQuarterlyGrowth', 'netIncomeToCommon', 'trailingEps', 'forwardEps', 'lastSplitFactor', 'lastSplitDate', 'enterpriseToRevenue', 'enterpriseToEbitda', '52WeekChange', 'SandP52WeekChange', 'exchange', 'quoteType', 'symbol', 'underlyingSymbol', 'shortName', 'longName', 'firstTradeDateEpochUtc', 'timeZoneFullName', 'timeZoneShortName', 'uuid', 'messageBoardId', 'gmtOffSetMilliseconds', 'currentPrice', 'targetHighPrice', 'targetLowPrice', 'targetMeanPrice', 'targetMedianPrice', 'recommendationMean', 'recommendationKey', 'numberOfAnalystOpinions', 'totalCash', 'totalCashPerShare', 'ebitda', 'totalDebt', 'quickRatio', 'currentRatio', 'totalRevenue', 'debtToEquity', 'revenuePerShare', 'returnOnAssets', 'returnOnEquity', 'freeCashflow', 'operatingCashflow', 'earningsGrowth', 'revenueGrowth', 'grossMargins', 'ebitdaMargins', 'operatingMargins', 'financialCurrency', 'trailingPegRatio'])
# address1: 1 Tesla Road
# city: Austin
# state: TX
# zip: 78725
# country: United States
# phone: 512 516 8177
# website: https://www.tesla.com
# industry: Auto Manufacturers
# industryKey: auto-manufacturers
# industryDisp: Auto Manufacturers
# sector: Consumer Cyclical
# sectorKey: consumer-cyclical
# sectorDisp: Consumer Cyclical
# longBusinessSummary: Tesla, Inc. designs, develops, manufactures, leases, and sells electric vehicles, and energy generation and storage systems in the United States, China, and internationally. The company operates in two segments, Automotive, and Energy Generation and Storage. The Automotive segment offers electric vehicles, as well as sells automotive regulatory credits; and non-warranty after-sales vehicle, used vehicles, body shop and parts, supercharging, retail merchandise, and vehicle insurance services. This segment also provides sedans and sport utility vehicles through direct and used vehicle sales, a network of Tesla Superchargers, and in-app upgrades; purchase financing and leasing services; services for electric vehicles through its company-owned service locations and Tesla mobile service technicians; and vehicle limited warranties and extended service plans. The Energy Generation and Storage segment engages in the design, manufacture, installation, sale, and leasing of solar energy generation and energy storage products, and related services to residential, commercial, and industrial customers and utilities through its website, stores, and galleries, as well as through a network of channel partners; and provision of service and repairs to its energy product customers, including under warranty, as well as various financing options to its solar customers. The company was formerly known as Tesla Motors, Inc. and changed its name to Tesla, Inc. in February 2017. Tesla, Inc. was incorporated in 2003 and is headquartered in Austin, Texas.
# fullTimeEmployees: 140473
# companyOfficers: [{'maxAge': 1, 'name': 'Mr. Elon R. Musk', 'age': 51, 'title': 'Co-Founder, Technoking of Tesla, CEO & Director', 'yearBorn': 1972, 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Vaibhav  Taneja', 'age': 45, 'title': 'Chief Financial Officer', 'yearBorn': 1978, 'fiscalYear': 2023, 'totalPay': 278000, 'exercisedValue': 8517957, 'unexercisedValue': 202075632}, {'maxAge': 1, 'name': 'Mr. Xiaotong  Zhu', 'age': 43, 'title': 'Senior Vice President of Automotive', 'yearBorn': 1980, 'fiscalYear': 2023, 'totalPay': 926877, 'exercisedValue': 0, 'unexercisedValue': 344144320}, {'maxAge': 1, 'name': 'Travis  Axelrod', 'title': 'Head of Investor Relations', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Brian  Scelfo', 'title': 'Senior Director of Corporate Development', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Franz  von Holzhausen', 'title': 'Chief Designer', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. John  Walker', 'age': 60, 'title': 'Vice President of Sales - North America', 'yearBorn': 1963, 'fiscalYear': 2023, 'totalPay': 121550, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Peter  Bannon', 'title': 'Chip Architect', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Turner  Caldwell', 'title': 'Engineering Manager', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Rodney D. Westmoreland Jr.', 'title': 'Director of Construction Management', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}]
# auditRisk: 7
# boardRisk: 9
# compensationRisk: 10
# shareHolderRightsRisk: 9
# overallRisk: 10
# governanceEpochDate: 1733011200
# compensationAsOfEpochDate: 1703980800
# maxAge: 86400
# priceHint: 2
# previousClose: 369.49
# open: 377.27
# dayLow: 370.8
# dayHigh: 389.49
# regularMarketPreviousClose: 369.49
# regularMarketOpen: 377.27
# regularMarketDayLow: 370.8
# regularMarketDayHigh: 389.49
# beta: 2.295
# trailingPE: 106.34426
# forwardPE: 118.947495
# volume: 78455915
# regularMarketVolume: 78455915
# averageVolume: 87199447
# averageVolume10days: 66887140
# averageDailyVolume10Day: 66887140
# bid: 372.0
# ask: 391.97
# bidSize: 100
# askSize: 200
# marketCap: 1249419591680
# fiftyTwoWeekLow: 138.8
# fiftyTwoWeekHigh: 389.49
# priceToSalesTrailing12Months: 12.860726
# fiftyDayAverage: 281.3716
# twoHundredDayAverage: 218.0677
# currency: USD
# enterpriseValue: 1229333463040
# profitMargins: 0.13075
# floatShares: 2793105010
# sharesOutstanding: 3210060032
# sharesShort: 76444266
# sharesShortPriorMonth: 79364249
# sharesShortPreviousMonthDate: 1728950400
# dateShortInterest: 1731628800
# sharesPercentSharesOut: 0.0238
# heldPercentInsiders: 0.12911999
# heldPercentInstitutions: 0.47907
# shortRatio: 0.74
# shortPercentOfFloat: 0.0273
# impliedSharesOutstanding: 3210060032
# bookValue: 21.806
# priceToBook: 17.849216
# lastFiscalYearEnd: 1703980800
# nextFiscalYearEnd: 1735603200
# mostRecentQuarter: 1727654400
# earningsQuarterlyGrowth: 0.169
# netIncomeToCommon: 12743000064
# trailingEps: 3.66
# forwardEps: 3.24
# lastSplitFactor: 3:1
# lastSplitDate: 1661385600
# enterpriseToRevenue: 12.654
# enterpriseToEbitda: 92.822
# 52WeekChange: 0.54121137
# SandP52WeekChange: 0.31426477
# exchange: NMS
# quoteType: EQUITY
# symbol: TSLA
# underlyingSymbol: TSLA
# shortName: Tesla, Inc.
# longName: Tesla, Inc.
# firstTradeDateEpochUtc: 1277818200
# timeZoneFullName: America/New_York
# timeZoneShortName: EST
# uuid: ec367bc4-f92c-397c-ac81-bf7b43cffaf7
# messageBoardId: finmb_27444752
# gmtOffSetMilliseconds: -18000000
# currentPrice: 389.22
# targetHighPrice: 421.0
# targetLowPrice: 116.0
# targetMeanPrice: 249.75786
# targetMedianPrice: 245.0
# recommendationMean: 2.77083
# recommendationKey: hold
# numberOfAnalystOpinions: 42
# totalCash: 33648001024
# totalCashPerShare: 10.482
# ebitda: 13244000256
# totalDebt: 12782999552
# quickRatio: 1.214
# currentRatio: 1.844
# totalRevenue: 97150001152
# debtToEquity: 18.078
# revenuePerShare: 30.457
# returnOnAssets: 0.04759
# returnOnEquity: 0.20389
# freeCashflow: 676625024
# operatingCashflow: 14478999552
# earningsGrowth: 0.17
# revenueGrowth: 0.078
# grossMargins: 0.18229
# ebitdaMargins: 0.13633001
# operatingMargins: 0.107889995
# financialCurrency: USD
# trailingPegRatio: 10.7914

# %%
def get_huggingface_embeddings(text, model_name="sentence-transformers/all-mpnet-base-v2"):
    """
    Generates embeddings for the given text using a specified Hugging Face model.

    Args:
        text (str): The input text to generate embeddings for.
        model_name (str): The name of the Hugging Face model to use.
                          Defaults to "sentence-transformers/all-mpnet-base-v2".

    Returns:
        np.ndarray: The generated embeddings as a NumPy array.
    """
    model = SentenceTransformer(model_name)
    return model.encode(text)


def cosine_similarity_between_sentences(sentence1, sentence2):
    """
    Calculates the cosine similarity between two sentences.

    Args:
        sentence1 (str): The first sentence for similarity comparison.
        sentence2 (str): The second sentence for similarity comparison.

    Returns:
        float: The cosine similarity score between the two sentences,
               ranging from -1 (completely opposite) to 1 (identical).

    Notes:
        Prints the similarity score to the console in a formatted string.
    """
    # Get embeddings for both sentences
    embedding1 = np.array(get_huggingface_embeddings(sentence1))
    embedding2 = np.array(get_huggingface_embeddings(sentence2))

    # Reshape embeddings for cosine_similarity function
    embedding1 = embedding1.reshape(1, -1)
    embedding2 = embedding2.reshape(1, -1)

    # Calculate cosine similarity
    similarity = cosine_similarity(embedding1, embedding2)
    similarity_score = similarity[0][0]
    print(f"Cosine similarity between the two sentences: {similarity_score:.4f}")
    return similarity_score


# Example usage
sentence1 = "I like walking to the park"
sentence2 = "I like running to the office"

similarity = cosine_similarity_between_sentences(sentence1, sentence2)
# Out:
# Cosine similarity between the two sentences: 0.6133

# %%
aapl_info = get_stock_info('AAPL')
print(aapl_info)
# Out:
# {'Ticker': 'AAPL', 'Name': 'Apple Inc.', 'Business Summary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.', 'City': 'Cupertino', 'State': 'CA', 'Country': 'United States', 'Industry': 'Consumer Electronics', 'Sector': 'Technology'}

# %%
aapl_description = aapl_info['Business Summary']

company_description = "I want to find companies that make smartphones and are headquarted in California"

similarity = cosine_similarity_between_sentences(aapl_description, company_description)
# Out:
# Cosine similarity between the two sentences: 0.3635

# %% [markdown]
# # Get all the Stocks in the Stock Market

# %% [markdown]
# First, we need to get the symbols (also known as tickers) of all the stocks in the stock market

# %%
def get_company_tickers():
    """
    Downloads and parses the Stock ticker symbols from the GitHub-hosted SEC company tickers JSON file.

    Returns:
        dict: A dictionary containing company tickers and related information.

    Notes:
        The data is sourced from the official SEC website via a GitHub repository:
        https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json
    """
    # URL to fetch the raw JSON file from GitHub
    url = "https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json"

    # Making a GET request to the URL
    response = requests.get(url)

    # Checking if the request was successful
    if response.status_code == 200:
        # Parse the JSON content directly
        company_tickers = json.loads(response.content.decode('utf-8'))

        # Optionally save the content to a local file for future use
        with open("company_tickers.json", "w", encoding="utf-8") as file:
            json.dump(company_tickers, file, indent=4)

        print("File downloaded successfully and saved as 'company_tickers.json'")
        return company_tickers
    else:
        print(f"Failed to download file. Status code: {response.status_code}")
        return None

company_tickers = get_company_tickers()
# Out:
# File downloaded successfully and saved as 'company_tickers.json'

# %%
len(company_tickers)
# Out:
# 9998

# %% [markdown]
# # Inserting Stocks into Pinecone
#
# **1. Create an account on [Pinecone.io](https://app.pinecone.io/)**
#
# **2. Create a new index called "stocks" and set the dimensions to 768. Leave the rest of the settings as they are.**
#
# ![Screenshot 2024-12-02 at 4 48 03 PM](https://github.com/user-attachments/assets/13b484da-cd00-4337-a4db-4779080eb42c)
#
#
# **3. Create an API Key for Pinecone**
#
# ![Screenshot 2024-11-24 at 10 44 37 PM](https://github.com/user-attachments/assets/e7feacc6-2bd1-472a-82e5-659f65624a88)
#
#
# **4. Store your Pinecone API Key within Google Colab's secrets section, and then enable access to it (see the blue checkmark)**
#
#
# ![Screenshot 2024-11-24 at 10 45 25 PM](https://github.com/user-attachments/assets/eaf73083-0b5f-4d17-9e0c-eab84f91b0bc)

# %%
pinecone_api_key = userdata.get("PINECONE_API_KEY")
os.environ['PINECONE_API_KEY'] = pinecone_api_key

index_name = "stocks"
namespace = "stock-descriptions2"

hf_embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
vectorstore = PineconeVectorStore(index_name=index_name, embedding=hf_embeddings)

pc = Pinecone(api_key=userdata.get("PINECONE_API_KEY"),)
pinecone_index = pc.Index(index_name)
# Out:
# <ipython-input-5-083f175105e1>:7: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   hf_embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# # Sequential Processing
#
# It will take very long to process all the stocks like this!

# %% [markdown]
# [![](https://mermaid.ink/img/pako:eNqNkl1rgzAUhv9KyMXYwF74cSVjYA0rhY6WKRQWe5FqWqU1cUm8GKX_ffmwa65Gc6Hn5LxvzmM8F1jzhsIUHgUZWlCiigG9MlwoXp_AqpPqdS_esmyzCsBivV7o10fxXgagLFbZDsxmb2COi44dzxRsBK-plDoBZSsoaXbuNPeU4941qWBBv0fKVEfOvud5yejh0NWdLr1U0LnMmts2eYhDMLsZgEHa3TV5aEXbEG-zZZnasiXfLMGnaScVeNKRHDiT1DNunRGF5pMFtUaAiCKe5h4hp84jHHks9mJ8mMjBRBOMrT9G45wommis84bjYThZHuPYwzA_xqeIHUU8UZjyYxDOiOIJwhj_uRKnzhOc3FHsdHgoiUNJJhRTfgzFGVEyoRijj0JZAwPYU9GTrtFjfDHbFVQt7WkFUx02RJzMMF21joyKFz-shqkSIw2g4OOxhemBnKXOxqEhiqKO6DHt_3YHwr44v-XXX7It6B4?type=png)](https://mermaid.live/edit#pako:eNqNkl1rgzAUhv9KyMXYwF74cSVjYA0rhY6WKRQWe5FqWqU1cUm8GKX_ffmwa65Gc6Hn5LxvzmM8F1jzhsIUHgUZWlCiigG9MlwoXp_AqpPqdS_esmyzCsBivV7o10fxXgagLFbZDsxmb2COi44dzxRsBK-plDoBZSsoaXbuNPeU4941qWBBv0fKVEfOvud5yejh0NWdLr1U0LnMmts2eYhDMLsZgEHa3TV5aEXbEG-zZZnasiXfLMGnaScVeNKRHDiT1DNunRGF5pMFtUaAiCKe5h4hp84jHHks9mJ8mMjBRBOMrT9G45wommis84bjYThZHuPYwzA_xqeIHUU8UZjyYxDOiOIJwhj_uRKnzhOc3FHsdHgoiUNJJhRTfgzFGVEyoRijj0JZAwPYU9GTrtFjfDHbFVQt7WkFUx02RJzMMF21joyKFz-shqkSIw2g4OOxhemBnKXOxqEhiqKO6DHt_3YHwr44v-XXX7It6B4)

# %%
for idx, stock in company_tickers.items():
    stock_ticker = stock['ticker']
    stock_data = get_stock_info(stock_ticker)
    stock_description = stock_data['Business Summary']

    print(f"Processing stock {idx} / {len(company_tickers)} :", stock_ticker)

    vectorstore_from_documents = PineconeVectorStore.from_documents(
        documents=[Document(page_content=stock_description, metadata=stock_data)],
        id=stock_ticker,
        embedding=hf_embeddings,
        index_name=index_name,
        namespace=namespace
    )
# Out:
# Processing stock 0 / 9998 : NVDA
# Processing stock 1 / 9998 : AAPL
# Processing stock 2 / 9998 : MSFT
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-0b4e6262b270> in <cell line: 1>()
#       6     print(f"Processing stock {idx} / {len(company_tickers)} :", stock_ticker)
#       7
# ----> 8     vectorstore_from_documents = PineconeVectorStore.from_documents(
#       9         documents=[Document(page_content=stock_description, metadata=stock_data)],
#      10         embedding=hf_embeddings,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/vectorstores/base.py in from_documents(cls, documents, embedding, **kwargs)
#     850                 kwargs["ids"] = ids
#     851
# --> 852         return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#     853
#     854     @classmethod
#
# /usr/local/lib/python3.10/dist-packages/langchain_pinecone/vectorstores.py in from_texts(cls, texts, embedding, metadatas, ids, batch_size, text_key, namespace, index_name, upsert_kwargs, pool_threads, embeddings_chunk_size, async_req, id_prefix, **kwargs)
#     581         pinecone = cls(pinecone_index, embedding, text_key, namespace, **kwargs)
#     582
# --> 583         pinecone.add_texts(
#     584             texts,
#     585             metadatas=metadatas,
#
# /usr/local/lib/python3.10/dist-packages/langchain_pinecone/vectorstores.py in add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, async_req, id_prefix, **kwargs)
#     277             chunk_ids = ids[i : i + embedding_chunk_size]
#     278             chunk_metadatas = metadatas[i : i + embedding_chunk_size]
# --> 279             embeddings = self._embedding.embed_documents(chunk_texts)
#     280             vector_tuples = zip(chunk_ids, embeddings, chunk_metadatas)
#     281             if async_req:
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/embeddings/huggingface.py in embed_documents(self, texts)
#     113             sentence_transformers.SentenceTransformer.stop_multi_process_pool(pool)
#     114         else:
# --> 115             embeddings = self.client.encode(
#     116                 texts, show_progress_bar=self.show_progress, **self.encode_kwargs
#     117             )
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, **kwargs)
#     619
#     620             with torch.no_grad():
# --> 621                 out_features = self.forward(features, **kwargs)
#     622                 if self.device.type == "hpu":
#     623                     out_features = copy.deepcopy(out_features)
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in forward(self, input, **kwargs)
#     686             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#     687             module_kwargs = {key: value for key, value in kwargs.items() if key in module_kwarg_keys}
# --> 688             input = module(input, **module_kwargs)
#     689         return input
#     690
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/models/Transformer.py in forward(self, features, **kwargs)
#     348             trans_features["token_type_ids"] = features["token_type_ids"]
#     349
# --> 350         output_states = self.auto_model(**trans_features, **kwargs, return_dict=False)
#     351         output_tokens = output_states[0]
#     352
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, input_ids, attention_mask, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, **kwargs)
#     542         head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     543         embedding_output = self.embeddings(input_ids=input_ids, position_ids=position_ids, inputs_embeds=inputs_embeds)
# --> 544         encoder_outputs = self.encoder(
#     545             embedding_output,
#     546             attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict, **kwargs)
#     332                 all_hidden_states = all_hidden_states + (hidden_states,)
#     333
# --> 334             layer_outputs = layer_module(
#     335                 hidden_states,
#     336                 attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, hidden_states, attention_mask, head_mask, position_bias, output_attentions, **kwargs)
#     301         outputs = self_attention_outputs[1:]  # add self attentions if we output attention weights
#     302
# --> 303         intermediate_output = self.intermediate(attention_output)
#     304         layer_output = self.output(intermediate_output, attention_output)
#     305         outputs = (layer_output,) + outputs
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, hidden_states)
#     255
#     256     def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
# --> 257         hidden_states = self.dense(hidden_states)
#     258         hidden_states = self.intermediate_act_fn(hidden_states)
#     259         return hidden_states
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %% [markdown]
# # Parallelizing
#
# [![](https://mermaid.ink/img/pako:eNqFk0uLgzAQgP_KkMOe7MHXRZaC1baXvsDCwqqHrGarVJMSE9hS-983NnWxULceRmf4Pp2MyQVlLCfIQweOTwXsw4SCuvw4Eiw7wqpsxPsXn_r-bmXAcrtdqts6WuwN2Ecr3wB__blJYTKZwixe45JCwKjgrKoI7zwXdphjlVXwwfiR8CbVH9BxdjPbqKxlJTAlTDbVuYXAjDUNZveSHWcZaRromkj_F61etIbire8Xpt2b9tDslvpCdHrRGYrddF6Ibi-6D4vsBjqcUWDe_NCMl0TAG6gfwwmEWOA7FlgasEYBWwP2KOBowBkFXA24Y4COoW61DRklLcwvQUHUHooEFrK53hHrAbkX7WdF51nRfVLUcX4fs8y6ObawMON-phvyI2CGRVakyEA14TUuc7XnL52ZIFGQmiTIU4855scEJfSqOCwFi840Q57gkhiIM3kokPeNq0Zl8pRjQcISq4NT_1VPmH4y1ufXXwdkCM8?type=png)](https://mermaid.live/edit#pako:eNqFk0uLgzAQgP_KkMOe7MHXRZaC1baXvsDCwqqHrGarVJMSE9hS-983NnWxULceRmf4Pp2MyQVlLCfIQweOTwXsw4SCuvw4Eiw7wqpsxPsXn_r-bmXAcrtdqts6WuwN2Ecr3wB__blJYTKZwixe45JCwKjgrKoI7zwXdphjlVXwwfiR8CbVH9BxdjPbqKxlJTAlTDbVuYXAjDUNZveSHWcZaRromkj_F61etIbire8Xpt2b9tDslvpCdHrRGYrddF6Ibi-6D4vsBjqcUWDe_NCMl0TAG6gfwwmEWOA7FlgasEYBWwP2KOBowBkFXA24Y4COoW61DRklLcwvQUHUHooEFrK53hHrAbkX7WdF51nRfVLUcX4fs8y6ObawMON-phvyI2CGRVakyEA14TUuc7XnL52ZIFGQmiTIU4855scEJfSqOCwFi840Q57gkhiIM3kokPeNq0Zl8pRjQcISq4NT_1VPmH4y1ufXXwdkCM8)

# %%
# Initialize tracking lists
successful_tickers = []
unsuccessful_tickers = []

# Load existing successful/unsuccessful tickers
try:
    with open('successful_tickers.txt', 'r') as f:
        successful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(successful_tickers)} successful tickers")
except FileNotFoundError:
    print("No existing successful tickers file found")

try:
    with open('unsuccessful_tickers.txt', 'r') as f:
        unsuccessful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(unsuccessful_tickers)} unsuccessful tickers")
except FileNotFoundError:
    print("No existing unsuccessful tickers file found")
# Out:
# Loaded 3899 successful tickers
# Loaded 117 unsuccessful tickers

# %% [markdown]
# # Perform RAG

# %%
def document_exists(index, doc_id, namespace=None):
    response = index.fetch(ids=[doc_id], namespace=namespace)
    return doc_id in response.get('vectors', {})

def process_stock(stock_ticker: str) -> str:
    # Skip if already processed
    if stock_ticker in successful_tickers:
        return f"Already processed {stock_ticker}"

    elif document_exists(pinecone_index, stock_ticker, namespace):
        with open('successful_tickers.txt', 'a') as f:
            f.write(f"{stock_ticker}\n")
        successful_tickers.append(stock_ticker)
        return f"Document already exists for {stock_ticker}"

    try:
        # Get and store stock data
        stock_data = get_stock_info(stock_ticker)
        stock_description = stock_data['Business Summary']

        # Store stock description in Pinecone
        vectorstore_from_texts = PineconeVectorStore.from_documents(
            documents=[Document(page_content=stock_description, metadata=stock_data)],
            ids=[stock_ticker],
            embedding=hf_embeddings,
            index_name=index_name,
            namespace=namespace
        )

        # Track success
        with open('successful_tickers.txt', 'a') as f:
            f.write(f"{stock_ticker}\n")
        successful_tickers.append(stock_ticker)

        return f"Processed {stock_ticker} successfully"

    except Exception as e:
        # Track failure
        with open('unsuccessful_tickers.txt', 'a') as f:
            f.write(f"{stock_ticker}\n")
        unsuccessful_tickers.append(stock_ticker)

        return f"ERROR processing {stock_ticker}: {e}"

def parallel_process_stocks(tickers: list, max_workers: int = 10) -> None:
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_ticker = {
            executor.submit(process_stock, ticker): ticker
            for ticker in tickers
        }

        for future in concurrent.futures.as_completed(future_to_ticker):
            ticker = future_to_ticker[future]
            try:
                result = future.result()
                print(result)

                # Stop on error
                if result.startswith("ERROR"):
                    print(f"Stopping program due to error in {ticker}")
                    executor.shutdown(wait=False)
                    raise SystemExit(1)

            except Exception as exc:
                print(f'{ticker} generated an exception: {exc}')
                print("Stopping program due to exception")
                executor.shutdown(wait=False)
                raise SystemExit(1)

# Prepare your tickers
tickers_to_process = [company_tickers[num]['ticker'] for num in company_tickers.keys()]

# Process them
parallel_process_stocks(tickers_to_process, max_workers=5)
# Out:
# Streaming output truncated to the last 5000 lines.
# Already processed AYI
# Already processed ESRT
# Already processed GL
# Already processed MAG
# Already processed ACVA
# Already processed EOLS
# Already processed VIAV
# Already processed BMA
# Already processed TIPT
# Already processed WERN
# Already processed FNB
# Already processed SNEX
# Already processed VET
# Already processed JGSMY
# Already processed WMS
# Already processed PEN
# Already processed SEZL
# Already processed THQ
# Already processed PHK
# Already processed KLIC
# Already processed RGEN
# Already processed SAIC
# Already processed HTGC
# Already processed MODG
# Already processed HAYW
# Already processed ETD
# Already processed EVTC
# Already processed JILL
# Already processed CRRFY
# Already processed SKX
# Already processed CAKE
# Already processed HUBG
# Already processed TCBK
# Already processed FROG
# Already processed HLIO
# Already processed PATH
# Already processed IQ
# Already processed HIX
# Already processed NOAH
# Already processed CPRX
# Already processed IPG
# Already processed CBSH
# Already processed BOH
# Already processed SPNS
# Already processed CDP
# Already processed REPX
# Already processed COMM
# Already processed TRUP
# Already processed MARA
# Already processed SITC
# Already processed DIOD
# Already processed WBS
# Already processed UEC
# Already processed DCI
# Already processed DMLP
# Already processed SLVM
# Already processed HTH
# Already processed CROX
# Already processed REX
# Already processed UAN
# Already processed DEC
# Already processed WWD
# Already processed MOG-A
# Already processed AMR
# Already processed NMM
# Already processed NEA
# Already processed EXAS
# Already processed HIO
# Already processed LSEA
# Already processed ADX
# Already processed GSM
# Already processed SATS
# Already processed PTCT
# Already processed EADSY
# Already processed IONQ
# Already processed STEW
# Already processed KNTK
# Already processed HBCP
# Already processed WS
# Already processed SHO
# Already processed TLN
# Already processed INGR
# Already processed DJCO
# Already processed LGIH
# Already processed PRK
# Already processed STWD
# Already processed AHL-PC
# Already processed FHI
# Already processed SMBC
# Already processed BLCO
# Already processed ZIMV
# Already processed SPB
# Already processed ORKA
# Already processed CHDN
# Already processed DOCS
# Already processed MLTX
# Already processed NTCT
# Already processed ABM
# Already processed PANW
# Already processed COOP
# Already processed GDV
# Already processed EXTR
# Already processed CMBT
# Already processed ARW
# Already processed USNA
# Already processed BLD
# Already processed GRBK
# Already processed BDC
# Already processed FBIN
# Already processed INFN
# Already processed HL
# Already processed OPFI
# Already processed BSX
# Already processed BIOX
# Already processed RSI
# Already processed ESNT
# Already processed HBNC
# Already processed PSN
# Already processed CMC
# Already processed LPLA
# Already processed BXMT
# Already processed BMEZ
# Already processed FIBK
# Already processed PTVE
# Already processed RGLD
# Already processed EXPI
# Already processed CNXC
# Already processed ABCL
# Already processed COP
# Already processed MTH
# Already processed CLVT
# Already processed R
# Already processed GDRX
# Already processed HPK
# Already processed HCC
# Already processed AXL
# Already processed AIT
# Already processed WING
# Already processed CGBD
# Already processed GRND
# Already processed KIND
# Already processed C
# Already processed EGO
# Already processed CSGS
# Already processed NPO
# Already processed SAH
# Already processed INSW
# Already processed TPG
# Already processed AZZ
# Already processed CCO
# Already processed PCOR
# Already processed RVMD
# Already processed GNW
# Already processed MMI
# Already processed FHB
# Already processed BHP
# Already processed GXO
# Already processed CCIX
# Already processed NLCP
# Already processed CSTL
# Already processed DUFRY
# Already processed AGO
# Already processed PSNY
# Already processed SEIC
# Already processed JJSF
# Already processed SARO
# Already processed SRCE
# Already processed RYTM
# Already processed ADUS
# Already processed TALO
# Already processed ARM
# Already processed IOVA
# Already processed BCPC
# Already processed TCPC
# Already processed GCI
# Already processed GLBE
# Already processed CCJ
# Already processed UE
# Already processed VBTX
# Already processed OR
# Already processed SMCI
# Already processed AIRS
# Already processed UUGRY
# Already processed BX
# Already processed EOI
# Already processed TJX
# Already processed CURB
# Already processed COLB
# Already processed NOVT
# Already processed CVBF
# Already processed ERO
# Already processed GSAT
# Already processed CNTA
# Already processed GES
# Already processed SOC
# Already processed PNW
# Already processed BRBR
# Already processed AIO
# Already processed GSBC
# Already processed CBT
# Already processed MUFG
# Already processed ZIM
# Already processed XHR
# Already processed MIR
# Already processed TIMB
# Already processed AKBA
# Already processed DIDIY
# Already processed SRRK
# Already processed DDI
# Already processed CACI
# Already processed AAL
# Already processed BVN
# Already processed SONO
# Already processed VAL
# Already processed KKR
# Already processed LSTR
# Already processed GCMG
# Already processed EVCM
# Already processed PDI
# Already processed IGR
# Already processed OLED
# Already processed BANR
# Already processed KEP
# Already processed SHOO
# Already processed RKLB
# Already processed RUM
# Already processed TEX
# Already processed MATW
# Already processed TTE
# Already processed OSIS
# Already processed ONB
# Already processed AOSL
# Already processed FRHC
# Already processed HNGKY
# Already processed TOST
# Already processed PLTK
# Already processed CLDX
# Already processed ENV
# Already processed AMPH
# Already processed DSEEY
# Already processed PEGRY
# Already processed MLR
# Already processed SHOP
# Already processed SBCF
# Already processed NUVL
# Already processed NWN
# Already processed LOT
# Already processed CURLF
# Already processed ALGM
# Already processed WSR
# Already processed NEWT
# Already processed TRAK
# Already processed BPYPP
# Already processed PCN
# Already processed RDEIY
# Already processed BIGZ
# Already processed LIF
# Already processed AMAT
# Already processed LOB
# Already processed SDHC
# Already processed AEO
# Already processed STAG
# Already processed GBX
# Already processed TSN
# Already processed BATRA
# Already processed COKE
# Already processed ERAS
# Already processed SLV
# Already processed JAG
# Already processed ASAN
# Already processed OPRA
# Already processed DOOO
# Already processed PFE
# Already processed CSIQ
# Already processed KD
# Already processed ASA
# Already processed RPD
# Already processed DAR
# Already processed AUTL
# Already processed AOS
# Already processed PENN
# Already processed WRD
# Already processed AR
# Already processed STEL
# Already processed BRC
# Already processed EFSC
# Already processed AZTA
# Already processed ETN
# Already processed CRVL
# Already processed SLGN
# Already processed HBT
# Already processed IRTC
# Already processed EXOD
# Already processed EXPE
# Already processed PTEN
# Already processed DAVA
# Already processed TDS
# Already processed ESLT
# Already processed STN
# Already processed LXFR
# Already processed GLDD
# Already processed UL
# Already processed VC
# Already processed FCN
# Already processed LFUS
# Already processed IBRX
# Already processed XNCR
# Already processed FLNC
# Already processed AMBP
# Already processed MSGE
# Already processed WOR
# Already processed EMRAF
# Already processed TPX
# Already processed HAFC
# Already processed ARCB
# Already processed EPRT
# Already processed UNP
# Already processed PRKS
# Already processed WTTR
# Already processed CLSK
# Already processed SLN
# Already processed RHP
# Already processed EME
# Already processed FRME
# Already processed OSBC
# Already processed AEG
# Already processed ORI
# Already processed KGS
# Already processed LEG
# Already processed BTG
# Already processed PLTR
# Already processed WVE
# Already processed VRNS
# Already processed VYX
# Already processed SID
# Already processed BCUCY
# Already processed DLY
# Already processed WTRG
# Already processed CRGY
# Already processed SEM
# Already processed NIO
# Already processed KN
# Already processed URBN
# Already processed HVT
# Already processed OMER
# Already processed SCHW
# Already processed MRRTY
# Already processed BIPC
# Already processed VTS
# Already processed SMKUY
# Already processed ELF
# Already processed TECK
# Already processed CXT
# Already processed SAND
# Already processed NVST
# Already processed TWST
# Already processed CLS
# Already processed WB
# Already processed WRBY
# Already processed CAPL
# Already processed SYK
# Already processed LKNCY
# Already processed NEOG
# Already processed LCID
# Already processed CERT
# Already processed CAR
# Already processed ONTO
# Already processed BVS
# Already processed ISPR
# Already processed HLNE
# Already processed GTLB
# Already processed CGEM
# Already processed U
# Already processed BHC
# Already processed HON
# Already processed CWST
# Already processed ENVX
# Already processed ROHCY
# Already processed AGM
# Already processed STC
# Already processed VOD
# Already processed JANX
# Already processed CVLG
# Already processed SQM
# Already processed PNFP
# Already processed AKR
# Already processed TDOC
# Already processed ACHC
# Already processed PGR
# Already processed SPXSY
# Already processed CELH
# Already processed VALN
# Already processed MCW
# Already processed MBUU
# Already processed AAON
# Already processed IPGP
# Already processed ORA
# Already processed DSGX
# Already processed ARVN
# Already processed SPR
# Already processed PINC
# Already processed NGD
# Already processed AMGN
# Already processed UMBF
# Already processed SFST
# Already processed PCRX
# Already processed BLTE
# Already processed WST
# Already processed ATKR
# Already processed WKC
# Already processed GLNG
# Already processed XPOF
# Already processed CART
# Already processed KVYO
# Already processed FCBC
# Already processed LOW
# Already processed AY
# Already processed BYD
# Already processed CWK
# Already processed HCP
# Already processed NAVI
# Already processed NHI
# Already processed EQC
# Already processed PL
# Already processed OI
# Already processed MTZ
# Already processed VNOM
# Already processed LQDT
# Already processed NWBO
# Already processed VAC
# Already processed UBER
# Already processed TNC
# Already processed STBA
# Already processed LPL
# Already processed MXCT
# Already processed CWBC
# Already processed WRB
# Already processed ENOV
# Already processed DRD
# Already processed MUSA
# Already processed TKO
# Already processed AWR
# Already processed CTS
# Already processed SLVYY
# Already processed BLK
# Already processed NFE
# Already processed AWI
# Already processed CRTO
# Already processed FHN
# Already processed ADPT
# Already processed OLN
# Already processed CRL
# Already processed IFS
# Already processed IBM
# Already processed IMCR
# Already processed NBIS
# Already processed GE
# Already processed NNE
# Already processed HPF
# Already processed EPAC
# Already processed MEJHY
# Already processed GSL
# Already processed GNRC
# Already processed CUYTY
# Already processed CMCSA
# Already processed VRN
# Already processed VRDN
# Already processed ATAT
# Already processed KYN
# Already processed REXR
# Already processed CCU
# Already processed MLCO
# Already processed MIESY
# Already processed DSGR
# Already processed GBCI
# Already processed COMP
# Already processed ADT
# Already processed CHEF
# Already processed TBBB
# Already processed T
# Already processed RA
# Already processed COOK
# Already processed CCK
# Already processed BRSP
# Already processed DOX
# Already processed FBK
# Already processed FSK
# Already processed RNG
# Already processed BDJ
# Already processed PBF
# Already processed GFS
# Already processed CENX
# Already processed BPOP
# Already processed VRE
# Already processed PRVA
# Already processed FFC
# Already processed SMAR
# Already processed PAG
# Already processed CIEN
# Already processed BSM
# Already processed FDP
# Already processed WD
# Already processed PDD
# Already processed HKHC
# Already processed BMI
# Already processed MMSI
# Already processed WNC
# Already processed HDB
# Already processed PAR
# Already processed PCVX
# Already processed MRUS
# Already processed FRT
# Already processed HOPE
# Already processed ATMU
# Already processed SYBT
# Already processed DKL
# Already processed NTR
# Already processed VCEL
# Already processed WEX
# Already processed ARKO
# Already processed SLAB
# Already processed VNT
# Already processed NEE
# Already processed APG
# Already processed NAPA
# Already processed ALVO
# Already processed OTLY
# Already processed LEO
# Already processed WGO
# Already processed INDI
# Already processed RTX
# Already processed CON
# Already processed QRVO
# Already processed YETI
# Already processed FAF
# Already processed DVAX
# Already processed STR
# Already processed EAD
# Already processed AVDX
# Already processed MRX
# Already processed TECH
# Already processed DTM
# Already processed RAPP
# Already processed UBSI
# Already processed DV
# Already processed EL
# Already processed SIGI
# Already processed SPT
# Already processed BRZE
# Already processed LOCO
# Already processed CPF
# Already processed SPGI
# Already processed MTX
# Already processed SNN
# Already processed MOD
# Already processed SNX
# Already processed BTU
# Already processed TXG
# Already processed ALKT
# Already processed LU
# Already processed GPCR
# Already processed STM
# Already processed HWKN
# Already processed GNTX
# Already processed WDI
# Already processed KNSL
# Already processed SXT
# Already processed PRCT
# Already processed AS
# Already processed ANDE
# Already processed CBU
# Already processed EQBK
# Already processed BFST
# Already processed KTF
# Already processed HTD
# Already processed REYN
# Already processed VZ
# Already processed WFRD
# Already processed NICE
# Already processed APAM
# Already processed VEON
# Already processed DEI
# Already processed RY
# Already processed OMCL
# Already processed RBC
# Already processed USA
# Already processed ESPR
# Already processed ENVA
# Already processed GNK
# Already processed WTS
# Already processed TX
# Already processed TU
# Already processed IRDM
# Already processed MYRG
# Already processed GH
# Already processed MRNO
# Already processed DHR
# Already processed KIKOY
# Already processed MEDP
# Document already exists for RLEA
# Document already exists for RBTK
# Document already exists for PGEN
# Document already exists for LFMD
# Document already exists for AUDC
# Document already exists for EVI
# Document already exists for ELDN
# Document already exists for EVBN
# Document already exists for TLS
# Document already exists for CYBN
# Document already exists for NPV
# Document already exists for TCI
# Document already exists for MBCN
# Document already exists for LFCR
# Document already exists for ILPT
# Document already exists for INGN
# Document already exists for TSI
# Document already exists for BMEA
# Document already exists for HIE
# Document already exists for ONIT
# Document already exists for LCNB
# Document already exists for STRO
# Document already exists for TBRG
# Document already exists for CFFI
# Document already exists for EVM
# Document already exists for NCZ
# Document already exists for MVST
# Document already exists for LXEO
# Document already exists for CRNT
# Document already exists for TCRX
# Document already exists for FINW
# Document already exists for FUND
# Document already exists for MODV
# Document already exists for ASUR
# Document already exists for EVC
# Document already exists for MFM
# Document already exists for MVT
# Document already exists for MUE
# Document already exists for ACB
# Document already exists for VABK
# Document already exists for BRCC
# Document already exists for MQT
# Document already exists for AOMR
# Document already exists for AZI
# Document already exists for UTMD
# Document already exists for NXDT
# Document already exists for ISTR
# Document already exists for IVA
# Document already exists for ESOA
# Document already exists for PHT
# Document already exists for ALTG
# Document already exists for NHS
# Document already exists for PWOD
# Document already exists for CPSS
# Document already exists for CLPR
# Document already exists for PLL
# Document already exists for CLBR
# Document already exists for CIA
# Document already exists for FATE
# Document already exists for ACRV
# Document already exists for ADCT
# Document already exists for BCBP
# Document already exists for CFNB
# Document already exists for FF
# Document already exists for NRGV
# Document already exists for MGNX
# Document already exists for AENT
# Document already exists for DHY
# Document already exists for TTEC
# Document already exists for FUNC
# Document already exists for ACV
# Document already exists for CAF
# Document already exists for OBIO
# Document already exists for TATT
# Document already exists for FTK
# Document already exists for GTE
# Document already exists for GLO
# Document already exists for CTGO
# Document already exists for NC
# Document already exists for SRG
# Document already exists for LNZA
# Document already exists for AMPX
# Document already exists for MFIN
# Document already exists for BSEM
# Document already exists for MACI
# Document already exists for HMST
# Document already exists for TDF
# Document already exists for WEWA
# Document already exists for VTN
# Document already exists for ARL
# Document already exists for EDIT
# Document already exists for OKUR
# Document already exists for AILE
# Document already exists for GROY
# Document already exists for HWBK
# Document already exists for ZURA
# Document already exists for TSSI
# Document already exists for GOAI
# Document already exists for FXNC
# Document already exists for MYPS
# Document already exists for MHI
# Document already exists for TZOO
# Document already exists for CMCL
# Document already exists for GPJA
# Document already exists for ONL
# Document already exists for JOF
# Document already exists for LGI
# Document already exists for KNOP
# Document already exists for TRVI
# Document already exists for SANG
# Document already exists for GDRZF
# Document already exists for DBB
# Document already exists for GASS
# Document already exists for RGCO
# Document already exists for HITI
# Document already exists for BNTC
# Document already exists for KVAC
# Document already exists for STRS
# Document already exists for SERA
# Document already exists for EOD
# Document already exists for BKN
# Document already exists for SMID
# Document already exists for IVCB
# Document already exists for TMQ
# Document already exists for FOA
# Document already exists for AMRN
# Document already exists for VLN
# Document already exists for MAV
# Document already exists for MIO
# Document already exists for ESSA
# Document already exists for ENTA
# Document already exists for HQI
# Document already exists for PESI
# Document already exists for FFNW
# Document already exists for BTOC
# Document already exists for SWKH
# Document already exists for TBI
# Document already exists for CLYM
# Document already exists for INZY
# Document already exists for DC
# Document already exists for CRBP
# Document already exists for GHIX
# Document already exists for XBIT
# Document already exists for ESCA
# Document already exists for REEMF
# Document already exists for MOLN
# Document already exists for CORBF
# Document already exists for ETX
# Document already exists for ASPC
# Document already exists for MXF
# Document already exists for FXE
# Document already exists for INBX
# Document already exists for VSTA
# Document already exists for SLDB
# Document already exists for KGNR
# Document already exists for YIBO
# Document already exists for PCF
# Document already exists for FSFG
# Document already exists for DBP
# Document already exists for RELL
# Document already exists for MITT
# Document already exists for VRDR
# Document already exists for MED
# Document already exists for DMB
# Document already exists for AEVA
# Document already exists for LPA
# Document already exists for HURA
# Document already exists for ZJYL
# Document already exists for SPCE
# Document already exists for NKSH
# Document already exists for ODV
# Document already exists for CIO
# Document already exists for MYFW
# Document already exists for MVIS
# Document already exists for BDSX
# Document already exists for NKTR
# Document already exists for SKIN
# Document already exists for ENJ
# Document already exists for EPM
# Document already exists for PROF
# Document already exists for OPP
# Document already exists for SEVN
# Document already exists for PVBC
# Document already exists for QRTEA
# Document already exists for ALCO
# Document already exists for BETR
# Document already exists for EMX
# Document already exists for BNIGF
# Document already exists for AERG
# Document already exists for EMF
# Document already exists for HOFT
# Document already exists for TROO
# Document already exists for KYTX
# Document already exists for SGHT
# Document already exists for SIFY
# Document already exists for NNBR
# Document already exists for SVCO
# Document already exists for PCK
# Document already exists for FSP
# Document already exists for HYB
# Document already exists for MTWO
# Document already exists for EMP
# Document already exists for CMPX
# Document already exists for RMBL
# Document already exists for BSII
# Document already exists for WIA
# Document already exists for AFCG
# Document already exists for IRBT
# Document already exists for HPAI
# Document already exists for GPRO
# Document already exists for RAIL
# Document already exists for FULC
# Document already exists for WNEB
# Document already exists for FT
# Document already exists for AKA
# Document already exists for WBX
# Document already exists for BVFL
# Document already exists for BSL
# Document already exists for DHF
# Document already exists for TSVT
# Document already exists for INSI
# Document already exists for SHIP
# Document already exists for FCCO
# Document already exists for LANV
# Document already exists for PCQ
# Document already exists for EP
# Document already exists for NBTX
# Document already exists for RTC
# Document already exists for EACO
# Document already exists for AMTX
# Document already exists for SLDP
# Document already exists for CHGG
# Document already exists for INFU
# Document already exists for CLLS
# Document already exists for ICTSF
# Document already exists for AOAO
# Document already exists for FET
# Document already exists for EM
# Document already exists for OXSQ
# Document already exists for SRI
# Document already exists for ELLO
# Document already exists for CRBU
# Document already exists for IGI
# Document already exists for TIL
# Document already exists for PERF
# Document already exists for PROP
# Document already exists for PAYS
# Document already exists for RDCM
# Document already exists for SJT
# Document already exists for CAMP
# Document already exists for NRO
# Document already exists for MPV
# Document already exists for VBF
# Document already exists for MRCC
# Document already exists for HFFG
# Document already exists for HRTX
# Document already exists for NKTX
# Document already exists for VSTM
# Document already exists for ISBA
# Document already exists for NRDY
# Document already exists for PLCE
# Document already exists for CFBK
# Document already exists for SKGR
# Document already exists for NEOV
# Document already exists for DMAC
# Document already exists for ENX
# Document already exists for AVNW
# Document already exists for RMNI
# Document already exists for GDO
# Document already exists for SPKL
# Document already exists for ARAY
# Document already exists for JRVR
# Document already exists for GALT
# Document already exists for AVD
# Document already exists for GNSS
# Document already exists for SAMG
# Document already exists for FLC
# Document already exists for TCX
# Document already exists for EML
# Document already exists for IDE
# Document already exists for BRKH
# Document already exists for DOUG
# Document already exists for LFVN
# Document already exists for SMHI
# Document already exists for HGLB
# Document already exists for GLDG
# Document already exists for NANX
# Document already exists for GOSS
# Document already exists for STXS
# Document already exists for RCMT
# Document already exists for MDWD
# Document already exists for CDLX
# Document already exists for AXR
# Document already exists for GLSI
# Document already exists for ATOM
# Document already exists for BRLT
# Document already exists for ACTU
# Document already exists for SCPH
# Document already exists for TEAF
# Document already exists for BXSY
# Document already exists for NVRO
# Document already exists for TDAC
# Document already exists for TWIN
# Document already exists for ALCY
# Document already exists for CLAR
# Document already exists for SENS
# Document already exists for PLG
# Document already exists for STRT
# Document already exists for DXLG
# Document already exists for PTMN
# Document already exists for AZ
# Document already exists for LOGC
# Document already exists for ATLO
# Document already exists for JYNT
# Document already exists for GEOS
# Document already exists for FRGE
# Document already exists for ATOS
# Document already exists for UBFO
# Document already exists for III
# Document already exists for SPE
# Document already exists for EVE
# Document already exists for BAER
# Document already exists for FLL
# Document already exists for PLNH
# Document already exists for EARN
# Document already exists for UNG
# Document already exists for MAPS
# Document already exists for ADUR
# Document already exists for BGX
# Document already exists for GRUSF
# Document already exists for TDTH
# Document already exists for GPMT
# Document already exists for ELA
# Document already exists for MRBK
# Document already exists for BOOM
# Document already exists for MHLD
# Document already exists for PZC
# Document already exists for VYEY
# Document already exists for BW
# Document already exists for LCTX
# Document already exists for EUDA
# Document already exists for OGI
# Document already exists for ORGN
# Document already exists for IBAC
# Document already exists for ATGL
# Document already exists for CIK
# Document already exists for GRX
# Document already exists for MPA
# Document already exists for FACT
# Document already exists for FLD
# Document already exists for ESHA
# Document already exists for NNY
# Document already exists for CKPT
# Document already exists for ACU
# Document already exists for ITRG
# Document already exists for DRTS
# Document already exists for MDV
# Document already exists for LDDD
# Document already exists for NIU
# Document already exists for MMLP
# Document already exists for BMN
# Document already exists for PIM
# Document already exists for WILC
# Document already exists for BFIN
# Document already exists for AMLI
# Document already exists for MHF
# Document already exists for DLNG
# Document already exists for RCKY
# Document already exists for CBNA
# Document already exists for NUTX
# Document already exists for HCVI
# Document already exists for EHI
# Document already exists for TUSK
# Document already exists for TNYA
# Document already exists for STHO
# Document already exists for NMG
# Document already exists for MPTI
# Document already exists for BLNK
# Document already exists for BROG
# Document already exists for RFAI
# Document already exists for BFAC
# Document already exists for IDR
# Document already exists for FNRN
# Document already exists for MSD
# Document already exists for ACRS
# Document already exists for TSQ
# Document already exists for BWAY
# Document already exists for MAXN
# Document already exists for HNVR
# Document already exists for SSP
# Document already exists for CABA
# Document already exists for CZWI
# Document already exists for PEBK
# Document already exists for DSY
# Document already exists for EGAN
# Document already exists for ADAP
# Document already exists for BKUH
# Document already exists for SGMT
# Document already exists for DMF
# Document already exists for PDEX
# Document already exists for BDTX
# Document already exists for EVG
# Document already exists for LAKE
# Document already exists for FGBI
# Document already exists for MCN
# Document already exists for ARC
# Document already exists for BANX
# Document already exists for CBFV
# Document already exists for ERDCF
# Document already exists for DM
# Document already exists for VOXX
# Document already exists for VRA
# Document already exists for ACHV
# Document already exists for NKLA
# Document already exists for CYDY
# Document already exists for SKYE
# Document already exists for FRAF
# Document already exists for DIBS
# Document already exists for CMT
# Document already exists for SSTI
# Document already exists for SCWO
# Document already exists for ZEO
# Document already exists for WHG
# Document already exists for IGA
# Document already exists for PFD
# Document already exists for ABOS
# Document already exists for SLND
# Document already exists for ISRL
# Document already exists for CMXC
# Document already exists for CTRN
# Document already exists for CRAWA
# Document already exists for INSG
# Document already exists for POWW
# Document already exists for CCRD
# Document already exists for HFUS
# Document already exists for BZUN
# Document already exists for QSG
# Document already exists for ADVM
# Document already exists for MYO
# Document already exists for UEIC
# Document already exists for EDF
# Document already exists for RILY
# Document already exists for ASM
# Document already exists for GAIA
# Document already exists for CRDL
# Document already exists for HURC
# Document already exists for KRMD
# Document already exists for PDCC
# Document already exists for ALLT
# Document already exists for EHTH
# Document already exists for QRHC
# Document already exists for CSTE
# Document already exists for VGES
# Document already exists for GGR
# Document already exists for BTA
# Document already exists for SPPP
# Document already exists for NAZ
# Document already exists for BWG
# Document already exists for CNTX
# Document already exists for DCF
# Document already exists for CWGL
# Document already exists for UNB
# Document already exists for AJX
# Document already exists for MHH
# Document already exists for FTLF
# Document already exists for MPAA
# Document already exists for MX
# Document already exists for PHX
# Document already exists for TAYD
# Document already exists for AFBI
# Document already exists for ARBE
# Document already exists for SEER
# Document already exists for APPS
# Document already exists for BCOV
# Document already exists for DMO
# Document already exists for ECBK
# Document already exists for FNWD
# Document already exists for BRLS
# Document already exists for RMBI
# Document already exists for GGT
# Document already exists for SBFG
# Document already exists for TOYO
# Document already exists for VTYX
# Document already exists for IAUX
# Document already exists for CXDO
# Document already exists for ATEK
# Document already exists for GF
# Document already exists for CBUS
# Document already exists for RMMZ
# Document already exists for EBMT
# Document already exists for GAUZ
# Document already exists for KOPN
# Document already exists for JHS
# Document already exists for MNSB
# Document already exists for CGEN
# Document already exists for RPMT
# Document already exists for CRDF
# Document already exists for SUAC
# Document already exists for MNTN
# Document already exists for LFT
# Document already exists for VXRT
# Document already exists for CAAS
# Document already exists for VFL
# Document already exists for ZOM
# Document already exists for AVTX
# Document already exists for PEPG
# Document already exists for WEA
# Document already exists for FREVS
# Document already exists for IKT
# Document already exists for RANI
# Document already exists for ISSC
# Document already exists for ZLSSF
# Document already exists for VGAS
# Document already exists for SRV
# Document already exists for PHYTF
# Document already exists for ECF
# Document already exists for AMWL
# Document already exists for GATE
# Document already exists for LGO
# Document already exists for REE
# Document already exists for TOUR
# Document already exists for SFBC
# Document already exists for FMN
# Document already exists for MRAM
# Document already exists for HEQ
# Document already exists for FTCO
# Document already exists for ZTEK
# Document already exists for VIGL
# Document already exists for ACR
# Document already exists for NHHS
# Document already exists for BSET
# Document already exists for CRNC
# Document already exists for SRTS
# Document already exists for CNTY
# Document already exists for OTLK
# Document already exists for FCEL
# Document already exists for GEDC
# Document already exists for YXT
# Document already exists for KINS
# Document already exists for GLQ
# Document already exists for MAMO
# Document already exists for KGEI
# Document already exists for CSLR
# Document already exists for PIII
# Document already exists for HCIL
# Document already exists for ULBI
# Document already exists for LCUT
# Document already exists for CHSN
# Document already exists for CADL
# Document already exists for ORIS
# Document already exists for IPHA
# Document already exists for SAVE
# Document already exists for DLTH
# Document already exists for NXG
# Document already exists for FGFH
# Document already exists for RPTX
# Document already exists for RMGCF
# Document already exists for VOXR
# Document already exists for CSPI
# Document already exists for EMYB
# Document already exists for EPSN
# Document already exists for ZVIA
# Document already exists for JHI
# Document already exists for CCFN
# Document already exists for TSE
# Document already exists for CMCM
# Document already exists for DBE
# Document already exists for DRTTF
# Document already exists for TLYS
# Document already exists for NTIC
# Document already exists for FXY
# Document already exists for ASFH
# Document already exists for FEIM
# Document already exists for ELUT
# Document already exists for PHD
# Document already exists for ANRO
# Document already exists for LARK
# Document already exists for DTI
# Document already exists for CHN
# Document already exists for ANL
# Document already exists for PBYI
# Document already exists for QNBC
# Document already exists for EFSI
# Document already exists for XNET
# Document already exists for CATO
# Document already exists for TLSI
# Document already exists for CXE
# Document already exists for IAF
# Document already exists for PLAO
# Document already exists for ALYAF
# Document already exists for PAI
# Document already exists for OCCI
# Document already exists for IFRX
# Document already exists for WMPN
# Document already exists for OVBC
# Document already exists for TELA
# Document already exists for PFO
# Document already exists for FFMGF
# Document already exists for TPZ
# Document already exists for IMPP
# Document already exists for APXI
# Document already exists for CSTAF
# Document already exists for EPRX
# Document already exists for SRL
# Document already exists for BYNO
# Document already exists for SSSS
# Document already exists for SKIL
# Document already exists for VERI
# Document already exists for AKYA
# Document already exists for MNTX
# Document already exists for BEEP
# Document already exists for VBFC
# Document already exists for PFIE
# Document already exists for TRVG
# Document already exists for USAS
# Document already exists for CHEB
# Document already exists for BZFD
# Document already exists for CGO
# Document already exists for MRT
# Document already exists for ATLX
# Document already exists for QMMM
# Document already exists for SKYX
# Document already exists for HTCO
# Document already exists for AOUT
# Document already exists for CFFS
# Document already exists for DLHC
# Document already exists for QH
# Document already exists for FCAP
# Document already exists for PLMJ
# Document already exists for PPIH
# Document already exists for SBI
# Document already exists for PCSC
# Document already exists for NIM
# Document already exists for SHMD
# Document already exists for GIFI
# Document already exists for FENC
# Document already exists for QIPT
# Document already exists for EVF
# Document already exists for NOTE
# Document already exists for TELO
# Document already exists for TRFE
# Document already exists for SIEB
# Document already exists for INO
# Document already exists for CCIF
# Document already exists for OPRT
# Document already exists for TLGY
# Document already exists for INMB
# Document already exists for BKTI
# Document already exists for CRGO
# Document already exists for GCTS
# Document already exists for WHEN
# Document already exists for KEQU
# Document already exists for LPTX
# Document already exists for NMT
# Document already exists for LTRX
# Document already exists for COYA
# Document already exists for BATL
# Document already exists for KNDI
# Document already exists for CSLM
# Document already exists for VREOF
# Document already exists for TDUP
# Document already exists for OFS
# Document already exists for ZBAO
# Document already exists for PPYA
# Document already exists for USGO
# Document already exists for RBKB
# Document already exists for BMBN
# Document already exists for DERM
# Document already exists for AIRG
# Document already exists for PROV
# Document already exists for THCH
# Document already exists for QSI
# Document already exists for FNGR
# Document already exists for GECC
# Document already exists for IPSC
# Document already exists for THCP
# Document already exists for KNIT
# Document already exists for CEP
# Document already exists for OPOF
# Document already exists for PLBY
# Document already exists for VNJA
# Document already exists for QUIK
# Document already exists for GBIO
# Document already exists for SFWL
# Document already exists for ALTO
# Document already exists for PBHC
# Document already exists for TKLF
# Document already exists for CPHC
# Document already exists for ALOT
# Document already exists for BSBK
# Document already exists for BCV
# Document already exists for CSBB
# Document already exists for VIOT
# Document already exists for ENBP
# Document already exists for RVSB
# Document already exists for BBXIA
# Document already exists for TPIC
# Document already exists for GGZ
# Document already exists for FBYD
# Document already exists for SUNS
# Document already exists for SWZ
# Document already exists for NEON
# Document already exists for ASMB
# Document already exists for PLX
# Document already exists for CDTX
# Document already exists for ALLK
# Document already exists for MVO
# Document already exists for FRD
# Document already exists for LEE
# Document already exists for UFI
# Document already exists for RMI
# Document already exists for IXAQF
# Document already exists for MHGU
# Document already exists for LTBR
# Document already exists for LVPA
# Document already exists for KVHI
# Document already exists for HNW
# Document already exists for OPAD
# Document already exists for DPCS
# Document already exists for KPTI
# Document already exists for TRX
# Document already exists for NCTY
# Document already exists for TBMC
# Document already exists for VRSSF
# Document already exists for MOND
# Document already exists for BOWN
# Document already exists for FNWB
# Document already exists for VEEA
# Document already exists for MGF
# Document already exists for ADAG
# Document already exists for ACNT
# Document already exists for SES
# Document already exists for FKYS
# Document already exists for JLS
# Document already exists for CHMX
# Document already exists for MPLN
# Document already exists for TTP
# Document already exists for ANIX
# Document already exists for GRWG
# Document already exists for SKK
# Document already exists for PETS
# Document already exists for CDIX
# Document already exists for AAWH
# Document already exists for KBLB
# Document already exists for CODA
# Document already exists for FONR
# Document already exists for NTPIF
# Document already exists for MNPR
# Document already exists for RFM
# Document already exists for ERH
# Document already exists for NVCT
# Document already exists for SRBK
# Document already exists for SOL
# Document already exists for RLFTY
# Document already exists for HBIO
# Document already exists for PYRGF
# Document already exists for HUHU
# Document already exists for CNDA
# Document already exists for NMI
# Document already exists for PCM
# Document already exists for ALAR
# Document already exists for AFJK
# Document already exists for BDMD
# Document already exists for KF
# Document already exists for SNCR
# Document already exists for GLU
# Document already exists for GDL
# Document already exists for DSAQ
# Document already exists for GLAC
# Document already exists for AE
# Document already exists for ANVS
# Document already exists for RSSS
# Document already exists for EVGR
# Document already exists for HLVX
# Document already exists for SND
# Document already exists for HYSR
# Document already exists for QETA
# Document already exists for ELRE
# Document already exists for MCRB
# Document already exists for GUTS
# Document already exists for IVVD
# Document already exists for NOBH
# Document already exists for STG
# Document already exists for CMTV
# Document already exists for RGLS
# Document already exists for BEOB
# Document already exists for DYCQ
# Document already exists for IHD
# Document already exists for PFX
# Document already exists for BUKS
# Document already exists for KLXE
# Document already exists for GNTA
# Document already exists for IVCA
# Document already exists for TLSA
# Document already exists for AYRWF
# Document already exists for STKS
# Document already exists for IMUX
# Document already exists for CITE
# Document already exists for CNGL
# Document already exists for WOK
# Document already exists for BKHA
# Document already exists for OCFT
# Document already exists for CURI
# Document already exists for PTHL
# Document already exists for INTT
# Document already exists for PMHG
# Document already exists for ORMP
# Document already exists for PGP
# Document already exists for PHUN
# Document already exists for GNT
# Document already exists for IROH
# Document already exists for BDCC
# Document already exists for FBLG
# Document already exists for RLMD
# Document already exists for EDAP
# Document already exists for CMU
# Document already exists for WAI
# Document already exists for GLXG
# Document already exists for SY
# Document already exists for MIST
# Document already exists for FAT
# Document already exists for PWUP
# Document already exists for FSHP
# Document already exists for UTGN
# Document already exists for SATL
# Document already exists for EHGO
# Document already exists for SKLZ
# Document already exists for DTSQ
# Document already exists for JUSHF
# Document already exists for LSF
# Document already exists for HSPO
# Document already exists for CHCI
# Document already exists for VGI
# Document already exists for PFTA
# Document already exists for VFF
# Document already exists for SST
# Document already exists for SLNG
# Document already exists for MNOV
# Document already exists for PRPL
# Document already exists for INVE
# Document already exists for CRVO
# Document already exists for THM
# Document already exists for SFDL
# Document already exists for SILC
# Document already exists for ATMC
# Document already exists for LGCL
# Document already exists for VERU
# Document already exists for VOC
# Document already exists for EVTL
# Document already exists for TBNK
# Document already exists for NXC
# Document already exists for OAKU
# Document already exists for BLUAF
# Document already exists for IH
# Document already exists for CASI
# Document already exists for SPWH
# Document already exists for DIT
# Document already exists for SACH
# Document already exists for MAYS
# Document already exists for LNSR
# Document already exists for VMCA
# Document already exists for IRRX
# Document already exists for WEL
# Document already exists for ARMP
# Document already exists for COE
# Document already exists for CVGI
# Document already exists for LATG
# Document already exists for MKFG
# Document already exists for IMAQ
# Document already exists for CURR
# Document already exists for CHMI
# Document already exists for PFBX
# Document already exists for MGYR
# Document already exists for RSKIA
# Document already exists for BLEU
# Document already exists for MASS
# Document already exists for WTRV
# Document already exists for PMVP
# Document already exists for AITR
# Document already exists for CBAT
# Document already exists for SUUN
# Document already exists for PNI
# Document already exists for HNNA
# Document already exists for ARBK
# Document already exists for ZNOG
# Document already exists for RRGB
# Document already exists for ESP
# Document already exists for BAYA
# Document already exists for HPH
# Document already exists for RENB
# Document already exists for PUCK
# Document already exists for GAN
# Document already exists for WCT
# Document already exists for IVFH
# Document already exists for CDAQF
# Document already exists for UNIB
# Document already exists for IKNA
# Document already exists for YTRA
# Document already exists for MDXH
# Document already exists for SLS
# Document already exists for ANLDF
# Document already exists for BRID
# Document already exists for AXTI
# Document already exists for GNLX
# Document already exists for DHX
# Document already exists for TGAA
# Document already exists for IMAB
# Document already exists for REKR
# Document already exists for ME
# Document already exists for PRLH
# Document already exists for PTZH
# Document already exists for CHRS
# Document already exists for JEQ
# Document already exists for JVSA
# Document already exists for YHNA
# Document already exists for HOWL
# Document already exists for TCOA
# Document already exists for NMS
# Document already exists for FCO
# Document already exists for ASYS
# Document already exists for WIMI
# Document already exists for TGLO
# Document already exists for INVZ
# Document already exists for DTF
# Document already exists for LILMF
# Document already exists for DMA
# Document already exists for ATMV
# Document already exists for PROC
# Document already exists for LASE
# Document already exists for IRAA
# Document already exists for CUE
# Document already exists for ACET
# Document already exists for AUBN
# Document already exists for QNCX
# Document already exists for CAPN
# Document already exists for PED
# Document already exists for CMCAF
# Document already exists for BCTF
# Document already exists for CBRG
# Document already exists for ELVA
# Document already exists for EURK
# Document already exists for RGC
# Document already exists for LSBK
# Document already exists for SCTH
# Document already exists for MSSA
# Document already exists for PORT
# Document already exists for LGCY
# Document already exists for UBCP
# Document already exists for PSQH
# Document already exists for VTSI
# Document already exists for PRKR
# Document already exists for CTOR
# Document already exists for BKRRF
# Document already exists for OCAX
# Document already exists for CEE
# Document already exists for LEV
# Document already exists for FMBM
# Document already exists for CMRX
# Document already exists for EPIX
# Document already exists for AISP
# Document already exists for IVCP
# Document already exists for BCAB
# Document already exists for CLRB
# Document already exists for LVO
# Document already exists for ASRT
# Document already exists for ODYS
# Document already exists for RMTI
# Document already exists for BOCN
# Document already exists for KULR
# Document already exists for BRAG
# Document already exists for FVN
# Document already exists for SDIG
# Document already exists for ONCY
# Document already exists for ESGL
# Document already exists for GLE
# Document already exists for EZOO
# Document already exists for GGAAF
# Document already exists for GCV
# Document already exists for SCLX
# Document already exists for SGA
# Document already exists for CLSD
# Document already exists for MITA
# Document already exists for OVID
# Document already exists for PDSB
# Document already exists for AVTE
# Document already exists for CMTL
# Document already exists for AREC
# Document already exists for CAHO
# Document already exists for AUID
# Document already exists for ELTK
# Document already exists for NOVV
# Document already exists for CEV
# Document already exists for USAU
# Document already exists for ACRG
# Document already exists for ECOR
# Document already exists for TETE
# Document already exists for CNF
# Document already exists for MCHX
# Document already exists for AEAE
# Document already exists for VCSA
# Document already exists for CTMX
# Document already exists for VTGN
# Document already exists for FUSB
# Document already exists for BHAC
# Document already exists for DIST
# Document already exists for ICCH
# Document already exists for RGT
# Document already exists for AHT
# Document already exists for NDP
# Document already exists for VANI
# Document already exists for KANP
# Document already exists for INAQ
# Document already exists for OWLT
# Document already exists for VLT
# Document already exists for PPSI
# Document already exists for GLV
# Document already exists for FRLA
# Document already exists for SHIM
# Document already exists for WW
# Document already exists for ARAT
# Document already exists for OPRX
# Document already exists for WPRT
# Document already exists for LPSN
# Document already exists for MYND
# Document already exists for WNLV
# Document already exists for UPLD
# Document already exists for LICN
# Document already exists for BKKT
# Document already exists for GGROU
# Document already exists for PGZ
# Document already exists for FOSL
# Document already exists for LBGJ
# Document already exists for DBVT
# Document already exists for DWNX
# Document already exists for MGX
# Document already exists for GWH
# Document already exists for VUZI
# Document already exists for IOR
# Document already exists for NOTV
# Document already exists for HAIA
# Document already exists for SOTK
# Document already exists for OPI
# Document already exists for GLXZ
# Document already exists for NVAC
# Document already exists for GLLI
# Document already exists for FDSB
# Document already exists for CCEL
# Document already exists for CCG
# Document already exists for ALVR
# Document already exists for SLBK
# Document already exists for BOLD
# ...
# Processed GSTK successfully
# Processed SPECW successfully
# Processed SOCGM successfully
# Processed MAQCU successfully
# Processed FBRT-PE successfully
# Processed MAQCW successfully
# Processed GRRRW successfully
# Processed WAL-PA successfully
# Processed ONBPP successfully
# Processed ONBPO successfully
# Processed PMBPF successfully
# Processed PBNAF successfully
# Processed PMMBF successfully
# Processed PPLOF successfully
# Processed LGNZZ successfully
# Processed PPLAF successfully
# Processed DJTWW successfully
# Processed FIISP successfully
# Processed LGNDZ successfully
# Processed LGNXZ successfully
# Processed LGNYZ successfully
# Processed SHPWQ successfully
# Processed MSEXP successfully
# Processed NEOVW successfully
# Processed GSMGW successfully
# Processed ASTLW successfully
# Processed RLNDF successfully
# Processed ACONW successfully
# Processed GHIXU successfully
# Processed NVVEW successfully
# Processed GHIXW successfully
# Processed XBPEW successfully
# Processed LATGU successfully
# Processed LATGF successfully
# Processed ECDAW successfully
# Processed QTZM successfully
# Processed GLLIR successfully
# Processed XALCX successfully
# Processed GLLIU successfully
# Processed GLLIW successfully
# Processed MDCXW successfully
# Processed GIGGW successfully
# Processed GIGGU successfully
# Processed MDPLD successfully
# Processed CADE-PA successfully
# Processed GBBKW successfully
# Processed ARGD successfully
# Processed LENDX successfully
# Processed GBBKR successfully
# Processed ARGO-PA successfully
# Processed TOGIW successfully
# Processed NPPXF successfully
# Processed PREJF successfully
# Processed CMPOW successfully
# Processed FOSLL successfully
# Processed GWH-WT successfully
# Processed FOACW successfully
# Processed ABLVW successfully
# Processed PIIIW successfully
# Processed AILEW successfully
# Processed CLNNW successfully
# Processed SICLQ successfully
# Processed CSTUF successfully
# Processed OTRKP successfully
# Processed BENFW successfully
# Processed CSTWF successfully
# Processed TCEYF successfully
# Processed TRPPF successfully
# Processed TCNCF successfully
# Processed TCENF successfully
# Processed TRPRF successfully
# Processed KKRS successfully
# Processed OCAXU successfully
# Processed OCAXW successfully
# Processed MCOMW successfully
# Processed TRPEF successfully
# Processed PFXNZ successfully
# Processed BOH-PB successfully
# Processed GDHLF successfully
# Processed BARK-WT successfully
# Processed NTWOU successfully
# Processed BOH-PA successfully
# Processed HLLY-WT successfully
# Processed OBTC successfully
# Processed RFACW successfully
# Processed RFACR successfully
# Processed LARAX successfully
# Processed RFACU successfully
# Processed ITOR successfully
# Processed NPWR-WT successfully
# Processed TLGYW successfully
# Processed NESRW successfully
# Processed TLGYU successfully
# Processed NUVWQ successfully
# Processed CLGDF successfully
# Processed BKSY-WT successfully
# Processed TSLTF successfully
# Processed TACPF successfully
# Processed TRNTF successfully
# Processed SBIGW successfully
# Processed CPER successfully
# Processed SATLW successfully
# Processed TRTX-PC successfully
# Processed USCI successfully
# Processed BPYPM successfully
# Processed LIDRW successfully
# Processed MDAIW successfully
# Processed EVLVW successfully
# Processed BPYPN successfully
# Processed CDAWF successfully
# Processed NFTM successfully
# Processed BPYPO successfully
# Processed CDAUF successfully
# Processed CTRVP successfully
# Processed SNV-PE successfully
# Processed AMJT successfully
# Processed WLLBW successfully
# Processed LBRDP successfully
# Processed RGTIW successfully
# Processed OASPW successfully
# Processed ZOOZW successfully
# Processed FGFPP successfully
# Processed GIGGF successfully
# Processed TMEF successfully
# Processed PTIXW successfully
# Processed MBAVW successfully
# Processed BSTT successfully
# Processed MBAVU successfully
# Processed BCSAU successfully
# Processed BCSAW successfully
# Processed PLAOW successfully
# Processed PLAOU successfully
# Processed SQLLW successfully
# Processed INVLW successfully
# Processed SVIX successfully
# Processed SLMUF successfully
# Processed SLMWF successfully
# Processed UVIX successfully
# Processed MNYWW successfully
# Processed AREBW successfully
# Processed PDSKX successfully
# Processed MSBIP successfully
# Processed NUKKW successfully
# Processed SKGRU successfully
# Processed GAB-PK successfully
# Processed SKGRW successfully
# Processed NE-WTA successfully
# Processed NE-WT successfully
# Processed NBLWF successfully
# Processed SUACW successfully
# Processed SUACU successfully
# Processed DDT successfully
# Processed ASCWF successfully
# Processed ASCRF successfully
# Processed ASUUF successfully
# Processed CTO-PA successfully
# Processed SVIIR successfully
# Processed SVIIU successfully
# Processed SNAXW successfully
# Processed SVIIW successfully
# Processed WLSS successfully
# Processed TNONW successfully
# Processed ATGAF successfully
# Processed USB-PS successfully
# Processed CRMLW successfully
# Processed ATGPF successfully
# Processed OCSAW successfully
# Processed USB-PQ successfully
# Processed USB-PR successfully
# Processed GIPRW successfully
# Processed FORLW successfully
# Processed EFC-PA successfully
# Processed EFC-PB successfully
# Processed TCBIO successfully
# Processed EFC-PC successfully
# Processed FORLU successfully
# Processed SWKHL successfully
# Processed WINVU successfully
# Processed WINVR successfully
# Processed WINVW successfully
# Processed TGAAW successfully
# Processed TGAAU successfully
# Processed EVEX-WT successfully
# Processed AERTW successfully
# Processed PAAPU successfully
# Processed GGROW successfully
# Processed EFC-PD successfully
# Processed EFC-PE successfully
# Processed NYMTZ successfully
# Processed NYMTL successfully
# Processed NYMTM successfully
# Processed CCIRU successfully
# Processed AISPW successfully
# Processed NYMTI successfully
# Processed EOSEW successfully
# Processed LLYVB successfully
# Processed OPINL successfully
# Processed LLYVK successfully
# Processed LLYVA successfully
# Processed RDW-WT successfully
# Processed ACABU successfully
# Processed ACABW successfully
# Processed MET-PF successfully
# Processed ABPWW successfully
# Processed MINR successfully
# Processed BEIGF successfully
# Processed HPE-PC successfully
# Processed HFRO-PA successfully
# Processed CBBBD successfully
# Processed PMTU successfully
# Processed MDRRP successfully
# Processed TIPLX successfully
# Processed PMT-PC successfully
# Processed PGYWW successfully
# Processed LMND-WT successfully
# Processed KIM-PN successfully
# Processed IMAQR successfully
# Processed IMAQU successfully
# Processed IMAQW successfully
# Processed DTSQU successfully
# Processed DTSQR successfully
# Processed EONR-WT successfully
# Processed HTZWW successfully
# Processed BTSGU successfully
# Processed RZLVW successfully
# Processed BFLY-WT successfully
# Processed QVCC successfully
# Processed LIANY successfully
# Processed BRQL successfully
# Processed CDROW successfully
# Processed OWLTW successfully
# Processed MSSAR successfully
# Processed MSSAU successfully
# Processed MSSAW successfully
# Processed RCB successfully
# Processed JFBRW successfully
# Processed RCC successfully
# Processed JVSAU successfully
# Processed JVSAR successfully
# Processed BXNCP successfully
# Processed RC-PE successfully
# Processed RC-PC successfully
# Processed DSHKO successfully
# Processed DSHKN successfully
# Processed DSHKP successfully
# Processed GPATW successfully
# Processed GPATU successfully
# Processed RZC successfully
# Processed CTDD successfully
# Processed IBACR successfully
# Processed BROGW successfully
# Processed IMPPP successfully
# Processed PTNRF successfully
# Processed PNMXO successfully
# Processed GAFC successfully
# Processed CCGWW successfully
# Processed WLDSW successfully
# Processed ORANY successfully
# Processed KUSA successfully
# Processed HHEGF successfully
# Processed KVACU successfully
# Processed KVACW successfully
# Processed BHFAM successfully
# Processed COBA successfully
# Processed HTIBP successfully
# Processed BHFAN successfully
# Processed ROCLU successfully
# Processed BHFAO successfully
# Processed UHGWW successfully
# Processed ROCLW successfully
# Processed PCTTU successfully
# Processed GLSTR successfully
# Processed GLSTU successfully
# Processed GLSTW successfully
# Processed PCTTW successfully
# Processed HROWM successfully
# Processed HROWL successfully
# Processed TBC successfully
# Processed ONMDW successfully
# Processed KDLYW successfully
# Processed SDAWW successfully
# Processed SONDW successfully
# Processed T-PA successfully
# Processed LOTWW successfully
# Processed T-PC successfully
# Processed EP-PC successfully
# Processed FSREI successfully
# Processed FSREM successfully
# Processed BOWNR successfully
# Processed BOWNU successfully
# Processed SFB successfully
# Processed LBYKV successfully
# Processed SF-PC successfully
# Processed SF-PD successfully
# Processed BRZHW successfully
# Processed LBYAV successfully
# Processed BRZH successfully
# Processed LANV-WT successfully
# Processed BRZHR successfully
# Processed GDLG successfully
# Processed PSFE-WT successfully
# Processed AGNCO successfully
# Processed RAJAF successfully
# Processed AGNCP successfully
# Processed AGNCL successfully
# Processed CGABL successfully
# Processed BLACR successfully
# Processed HMELF successfully
# Processed PRSTW successfully
# Processed BLACW successfully
# Processed BLACU successfully
# Processed OFSSH successfully
# Processed EVGRU successfully
# Processed MOVAA successfully
# Processed EVGRW successfully
# Processed GLCP successfully
# Processed GCTS-WT successfully
# Processed WGSWW successfully
# Processed NRSNW successfully
# Processed COCHW successfully
# Processed TCBPW successfully
# Processed EXEEL successfully
# Processed KPHMW successfully
# Processed EXEEZ successfully
# Processed EXEEW successfully
# Processed IXQUF successfully
# Processed MBINN successfully
# Processed MBINO successfully
# Processed MBINM successfully
# Processed IXQWF successfully
# Processed CUBB successfully
# Processed SMR-WT successfully
# Processed FLG-PU successfully
# Processed ATLEW successfully
# Processed OPP-PA successfully
# Processed BWBBP successfully
# Processed NIVFW successfully
# Processed OPP-PB successfully
# Processed FLG-PA successfully
# Processed QBTS-WT successfully
# Processed PSEC-PA successfully
# Processed MCAGR successfully
# Processed MCAGU successfully
# Processed QTIWW successfully
# Processed NKGNW successfully
# Processed SOUNW successfully
# Processed SYTAW successfully
# Processed NSA-PB successfully
# Processed ANKM successfully
# Processed EDBLW successfully
# Processed LPBBU successfully
# Processed SSRT successfully
# Processed UNTCW successfully
# Processed FTIIU successfully
# Processed PW-PA successfully
# Processed FTIIW successfully
# Processed JWSWF successfully
# Processed CMXCD successfully
# Processed JWSUF successfully
# Processed NOTE-WT successfully
# Processed AEFC successfully
# Processed BFRGW successfully
# Processed NXLIW successfully
# Processed SWVLW successfully
# Processed CPTNW successfully
# Processed ECXWW successfully
# Processed AFGD successfully
# Processed AFGE successfully
# Processed GETRW successfully
# Processed DFLIW successfully
# Processed AFGB successfully
# Processed SCHW-PJ successfully
# Processed LEV-WT successfully
# Processed HMLPF successfully
# Processed CLOER successfully
# Processed CLOEU successfully
# Processed LEV-WTA successfully
# Processed HTFC successfully
# Processed HTFB successfully
# Processed FGN successfully
# Processed HBANP successfully
# Processed HBANL successfully
# Processed HBANM successfully
# Processed PBMWW successfully
# Processed DESLF successfully
# Processed BODYW successfully
# Processed IRRXW successfully
# Processed IRRXU successfully
# Processed CSWCZ successfully
# Processed CNOBP successfully
# Processed ANG-PB successfully
# Processed SEATW successfully
# Processed NAMSW successfully
# Processed ANG-PA successfully
# Processed SKILW successfully
# Processed MNTN-UN successfully
# Processed MNTN-WT successfully
# Processed CPPTL successfully
# Processed ODVWZ successfully
# Processed BKHAU successfully
# Processed BKHAR successfully
# Processed GODNU successfully
# Processed GODNR successfully
# Processed DSX-WT successfully
# Processed AVPTW successfully
# Processed HTOOW successfully
# Processed PMVCW successfully
# Processed PMVCD successfully
# Processed ZEOWW successfully
# Processed LUXHP successfully
# Processed INTEU successfully
# Processed INTEW successfully
# Processed FAASW successfully
# Processed WEL-WT successfully
# Processed WELPM successfully
# Processed WEL-UN successfully
# Processed HPAIW successfully
# Processed HPP-PC successfully
# Processed FCNCO successfully
# Processed NWOEF successfully
# Processed FCNCP successfully
# Processed BFS-PE successfully
# Processed QOMOR successfully
# Processed NEWTZ successfully
# Processed QOMOU successfully
# Processed QOMOW successfully
# Processed NEWTG successfully
# Processed KORGW successfully
# Processed FREJP successfully
# Processed FMCKK successfully
# Processed C-PN successfully
# Processed AHL-PE successfully
# Processed NEWTH successfully
# Processed RWAYL successfully
# Processed RWAYZ successfully
# Processed ARBKL successfully
# Processed TFINP successfully
# Processed ATIPW successfully
# Processed ML-WT successfully
# Processed FRMEP successfully
# Processed LZM-WT successfully
# Processed HSCSW successfully
# Processed CINGW successfully
# Processed AEAEU successfully
# Processed ADVWW successfully
# Processed NIOBW successfully
# Processed AEAEW successfully
# Processed FRTSF successfully
# Processed FTPSF successfully
# Processed BRLSW successfully
# Processed CIVIW successfully
# Processed CIVII successfully
# Processed HNNAZ successfully
# Processed FORFF successfully
# Processed FRLAU successfully
# Processed FTRSF successfully
# Processed CCLDO successfully
# Processed CCLDP successfully
# Processed FRLAW successfully
# Processed TDBCP successfully
# Processed TDOMF successfully
# Processed STSR successfully
# Processed TDOPF successfully
# Processed TBLAW successfully
# Processed CWLXF successfully
# Processed CUBWW successfully
# Processed CUBWU successfully
# Processed TDBKF successfully
# Processed IRS-WT successfully
# Processed ANGHW successfully
# Processed PMFAX successfully
# Processed HYMCL successfully
# Processed GPUS-PD successfully
# Processed AAMCF successfully
# Processed HYMCW successfully
# Processed LFLYW successfully
# Processed KPLTW successfully
# Processed HPKEW successfully
# Processed LCFYW successfully
# Processed GL-PD successfully
# Processed LTSV successfully
# Processed FTCHQ successfully
# Processed LSEAW successfully
# Processed BLDEW successfully
# Processed TRXDW successfully
# Processed AGQ successfully
# Processed EUO successfully
# Processed BOIL successfully
# Processed GLL successfully
# Processed VIXY successfully
# Processed VIXM successfully
# Processed ZSL successfully
# Processed YCL successfully
# Processed YCS successfully
# Processed SVXY successfully
# Processed UCO successfully
# Processed UVXY successfully
# Processed UGL successfully
# Processed ULE successfully
# Processed KOLD successfully
# Processed SCO successfully
# Processed MFAN successfully
# Processed MFAO successfully
# Processed TANAF successfully
# Processed MFA-PC successfully
# Processed WSUPW successfully
# Processed SPE-PC successfully
# Processed GTECW successfully
# Processed AMPX-WT successfully
# Processed MLECW successfully
# Processed HUBCW successfully
# Processed FFIEW successfully
# Processed AGQPF successfully
# Processed AQNB successfully
# Processed GATEU successfully
# Processed GATEW successfully
# Processed FSEN successfully
# Processed HUBCZ successfully
# Processed DODRW successfully
# Processed LAAOF successfully
# Processed NVNIW successfully
# Processed HIPOW successfully
# Processed GLADZ successfully
# Processed FLDDW successfully
# Processed FLDDU successfully
# Processed FNVTW successfully
# Processed FNVWF successfully
# Processed FNVUF successfully
# Processed PRIF-PI successfully
# Processed PRIF-PJ successfully
# Processed PRIF-PL successfully
# Processed PRIF-PK successfully
# Processed PRIF-PD successfully
# Processed PRIF-PF successfully
# Processed PRIF-PG successfully
# Processed PRIF-PH successfully
# Processed KREF-PA successfully
# Processed ACZT successfully
# Processed BACQU successfully
# Processed YHNAR successfully
# Processed MTB-PH successfully
# Processed CELG-RI successfully
# Processed MTB-PJ successfully
# Processed YHNAU successfully
# Processed RMXI successfully
# Processed MKDWW successfully
# Processed FCCID successfully
# Processed UUGWF successfully
# Processed CYTHW successfully
# Processed ANZGF successfully

# %%
uploaded_stocks = []
for ids in pinecone_index.list(namespace=namespace):
    uploaded_stocks.extend(ids)

print(f"Uploaded stocks: {len(uploaded_stocks)}")
# Out:
# Uploaded stocks: 9998

# %%
# check if all stocks in tickers_to_process in uploaded_stocks
all(item in uploaded_stocks for item in tickers_to_process)
# Out:
# True

# %%
query = "What is the best stock to buy?"

# %%
raw_query_embedding = get_huggingface_embeddings(query)

# %%
top_matches = pinecone_index.query(vector=raw_query_embedding.tolist(), top_k=10, include_metadata=True, namespace=namespace)

# %%
top_matches
# Out:
# {'matches': [{'id': 'MKTW',
#               'metadata': {'Business Summary': 'MarketWise, Inc. operates a '
#                                                'content and technology '
#                                                'multi-brand platform for '
#                                                'self-directed investors in the '
#                                                'United States and '
#                                                'Internationally. Its platform '
#                                                'includes subscription '
#                                                'businesses that provides '
#                                                'financial research, software, '
#                                                'education, and tools to '
#                                                'navigate the financial '
#                                                'markets. The company offers '
#                                                'various investment strategies, '
#                                                'such as value investing, '
#                                                'income, growth, commodities, '
#                                                'cryptocurrencies, venture, '
#                                                'crowdfunded investing, '
#                                                'biotechnology, mutual funds, '
#                                                'options, and trading; '
#                                                'investment research product '
#                                                'portfolio through a range of '
#                                                'media, including desktops, '
#                                                'laptops, tablets, and mobile; '
#                                                'and financial newsletters. It '
#                                                'provides a suite of stock '
#                                                'research tools and portfolio '
#                                                'management services under the '
#                                                'Chaikin Analytics brand; '
#                                                'portfolio management software '
#                                                'tools under the TradeSmith '
#                                                'brand name; and database of '
#                                                'accounting-based financial '
#                                                'summaries under the Altimetry '
#                                                'brand. In addition, the '
#                                                'company develops screeners, '
#                                                'monitors, portfolio management '
#                                                'tools, and proprietary '
#                                                'indicators that produce a '
#                                                'composite score to rank '
#                                                'publicly traded companies. The '
#                                                'company was founded in 1999 '
#                                                'and is headquartered in '
#                                                'Baltimore, Maryland.',
#                            'City': 'Baltimore',
#                            'Country': 'United States',
#                            'Industry': 'Financial Data & Stock Exchanges',
#                            'Name': 'MarketWise, Inc.',
#                            'Sector': 'Financial Services',
#                            'State': 'MD',
#                            'Ticker': 'MKTW',
#                            'text': 'MarketWise, Inc. operates a content and '
#                                    'technology multi-brand platform for '
#                                    'self-directed investors in the United '
#                                    'States and Internationally. Its platform '
#                                    'includes subscription businesses that '
#                                    'provides financial research, software, '
#                                    'education, and tools to navigate the '
#                                    'financial markets. The company offers '
#                                    'various investment strategies, such as '
#                                    'value investing, income, growth, '
#                                    'commodities, cryptocurrencies, venture, '
#                                    'crowdfunded investing, biotechnology, '
#                                    'mutual funds, options, and trading; '
#                                    'investment research product portfolio '
#                                    'through a range of media, including '
#                                    'desktops, laptops, tablets, and mobile; '
#                                    'and financial newsletters. It provides a '
#                                    'suite of stock research tools and '
#                                    'portfolio management services under the '
#                                    'Chaikin Analytics brand; portfolio '
#                                    'management software tools under the '
#                                    'TradeSmith brand name; and database of '
#                                    'accounting-based financial summaries under '
#                                    'the Altimetry brand. In addition, the '
#                                    'company develops screeners, monitors, '
#                                    'portfolio management tools, and '
#                                    'proprietary indicators that produce a '
#                                    'composite score to rank publicly traded '
#                                    'companies. The company was founded in 1999 '
#                                    'and is headquartered in Baltimore, '
#                                    'Maryland.'},
#               'score': 0.449571788,
#               'values': []},
#              {'id': 'FNGU',
#               'metadata': {'Business Summary': 'The notes are intended to be '
#                                                'daily trading tools for '
#                                                'sophisticated investors to '
#                                                'manage daily trading risks as '
#                                                'part of an overall diversified '
#                                                'portfolio. The index is an '
#                                                'equal-dollar weighted index '
#                                                'designed to represent a '
#                                                'segment of the technology and '
#                                                'consumer discretionary sectors '
#                                                'consisting of highly-traded '
#                                                'growth stocks of technology '
#                                                'and tech-enabled companies.',
#                            'City': 'Information not available',
#                            'Country': 'Information not available',
#                            'Industry': 'Information not available',
#                            'Name': 'MicroSectors FANG+ Index 3X Leveraged ETN',
#                            'Sector': 'Information not available',
#                            'State': 'Information not available',
#                            'Ticker': 'FNGU',
#                            'text': 'The notes are intended to be daily trading '
#                                    'tools for sophisticated investors to '
#                                    'manage daily trading risks as part of an '
#                                    'overall diversified portfolio. The index '
#                                    'is an equal-dollar weighted index designed '
#                                    'to represent a segment of the technology '
#                                    'and consumer discretionary sectors '
#                                    'consisting of highly-traded growth stocks '
#                                    'of technology and tech-enabled companies.'},
#               'score': 0.406768531,
#               'values': []},
#              {'id': 'FNGD',
#               'metadata': {'Business Summary': 'The notes are intended to be '
#                                                'daily trading tools for '
#                                                'sophisticated investors to '
#                                                'manage daily trading risks as '
#                                                'part of an overall diversified '
#                                                'portfolio. The index is an '
#                                                'equal-dollar weighted index '
#                                                'designed to represent a '
#                                                'segment of the technology and '
#                                                'consumer discretionary sectors '
#                                                'consisting of highly-traded '
#                                                'growth stocks of technology '
#                                                'and tech-enabled companies.',
#                            'City': 'Information not available',
#                            'Country': 'Information not available',
#                            'Industry': 'Information not available',
#                            'Name': 'MicroSectors FANG+ Index -3X Inverse '
#                                    'Leveraged ETN',
#                            'Sector': 'Information not available',
#                            'State': 'Information not available',
#                            'Ticker': 'FNGD',
#                            'text': 'The notes are intended to be daily trading '
#                                    'tools for sophisticated investors to '
#                                    'manage daily trading risks as part of an '
#                                    'overall diversified portfolio. The index '
#                                    'is an equal-dollar weighted index designed '
#                                    'to represent a segment of the technology '
#                                    'and consumer discretionary sectors '
#                                    'consisting of highly-traded growth stocks '
#                                    'of technology and tech-enabled companies.'},
#               'score': 0.406768531,
#               'values': []},
#              {'id': 'QMCI',
#               'metadata': {'Business Summary': 'QuoteMedia, Inc. provides '
#                                                'financial data, market '
#                                                'research information, '
#                                                'analytics, news feeds, and '
#                                                'financial software solutions '
#                                                'to online brokerages, banks, '
#                                                'clearing firms, financial '
#                                                'service companies, media '
#                                                'portals, and public '
#                                                'corporations worldwide. It '
#                                                'collects, aggregates, and '
#                                                'delivers delayed and real-time '
#                                                'financial data content through '
#                                                'the Internet. The company also '
#                                                'offers market information and '
#                                                'services, including streaming '
#                                                'stock market data feeds, '
#                                                'research and analysis '
#                                                'information, content '
#                                                'applications, portfolio '
#                                                'management systems, software '
#                                                'products, corporate investor '
#                                                'relations provisioning, news '
#                                                'services, mobile apps, and '
#                                                'custom development. In '
#                                                'addition, its data feeds '
#                                                'coverage includes equities, '
#                                                'options, futures, commodities, '
#                                                'currencies, mutual funds, '
#                                                'ETFs, and indices. Further, '
#                                                'the company provides financial '
#                                                'data delivery application '
#                                                'products and components '
#                                                'comprising quote modules, '
#                                                'charts, market movers, news, '
#                                                'watch lists, tickers, market '
#                                                'summaries, option chains, '
#                                                'filings, fundamentals, '
#                                                'investor relations solutions, '
#                                                'stock and fund screeners, and '
#                                                'others; and QMod, a web '
#                                                'delivery system for delivering '
#                                                'market data content to Web '
#                                                'platforms. Additionally, it '
#                                                'offers portfolio managements '
#                                                'systems, including Quotestream '
#                                                'Desktop, We, and Mobile, a '
#                                                'Web-delivered, embedded '
#                                                'application providing '
#                                                'real-time, tick-by-tick, '
#                                                'streaming market quotes and '
#                                                'research information; '
#                                                'Quotestream Professional that '
#                                                'offers low-latency '
#                                                'tick-by-tick data, '
#                                                'customizable screens, advanced '
#                                                'charting, comprehensive '
#                                                'technical analysis, news, and '
#                                                'research data for financial '
#                                                'services professionals; Web '
#                                                'Portfolio Manager, which '
#                                                'provides immediate web access '
#                                                'to detailed quote data, market '
#                                                'and company news, charting, '
#                                                'depth/level II, filings, '
#                                                'historical data, snap quotes, '
#                                                'and others; and Quotestream '
#                                                'Connect that delivers real '
#                                                'time data feeds to individual '
#                                                'users to power third party '
#                                                'applications. The company was '
#                                                'incorporated in 1992 and is '
#                                                'headquartered in Fountain '
#                                                'Hills, Arizona.',
#                            'City': 'Fountain Hills',
#                            'Country': 'United States',
#                            'Industry': 'Financial Data & Stock Exchanges',
#                            'Name': 'QuoteMedia, Inc.',
#                            'Sector': 'Financial Services',
#                            'State': 'AZ',
#                            'Ticker': 'QMCI',
#                            'text': 'QuoteMedia, Inc. provides financial data, '
#                                    'market research information, analytics, '
#                                    'news feeds, and financial software '
#                                    'solutions to online brokerages, banks, '
#                                    'clearing firms, financial service '
#                                    'companies, media portals, and public '
#                                    'corporations worldwide. It collects, '
#                                    'aggregates, and delivers delayed and '
#                                    'real-time financial data content through '
#                                    'the Internet. The company also offers '
#                                    'market information and services, including '
#                                    'streaming stock market data feeds, '
#                                    'research and analysis information, content '
#                                    'applications, portfolio management '
#                                    'systems, software products, corporate '
#                                    'investor relations provisioning, news '
#                                    'services, mobile apps, and custom '
#                                    'development. In addition, its data feeds '
#                                    'coverage includes equities, options, '
#                                    'futures, commodities, currencies, mutual '
#                                    'funds, ETFs, and indices. Further, the '
#                                    'company provides financial data delivery '
#                                    'application products and components '
#                                    'comprising quote modules, charts, market '
#                                    'movers, news, watch lists, tickers, market '
#                                    'summaries, option chains, filings, '
#                                    'fundamentals, investor relations '
#                                    'solutions, stock and fund screeners, and '
#                                    'others; and QMod, a web delivery system '
#                                    'for delivering market data content to Web '
#                                    'platforms. Additionally, it offers '
#                                    'portfolio managements systems, including '
#                                    'Quotestream Desktop, We, and Mobile, a '
#                                    'Web-delivered, embedded application '
#                                    'providing real-time, tick-by-tick, '
#                                    'streaming market quotes and research '
#                                    'information; Quotestream Professional that '
#                                    'offers low-latency tick-by-tick data, '
#                                    'customizable screens, advanced charting, '
#                                    'comprehensive technical analysis, news, '
#                                    'and research data for financial services '
#                                    'professionals; Web Portfolio Manager, '
#                                    'which provides immediate web access to '
#                                    'detailed quote data, market and company '
#                                    'news, charting, depth/level II, filings, '
#                                    'historical data, snap quotes, and others; '
#                                    'and Quotestream Connect that delivers real '
#                                    'time data feeds to individual users to '
#                                    'power third party applications. The '
#                                    'company was incorporated in 1992 and is '
#                                    'headquartered in Fountain Hills, Arizona.'},
#               'score': 0.387640446,
#               'values': []},
#              {'id': 'HDLB',
#               'metadata': {'Business Summary': 'The index is designed to '
#                                                'measure the performance of 40 '
#                                                'dividend yielding, relatively '
#                                                'lower volatility Index '
#                                                'Constituent Securities from '
#                                                'the universe of the largest '
#                                                '1,000 U.S. listed stocks by '
#                                                'market capitalization, as '
#                                                'described herein. The '
#                                                'Securities seek to approximate '
#                                                'the monthly returns that might '
#                                                'be available to investors '
#                                                'through a leveraged “long” '
#                                                'investment in the index '
#                                                'constituent securities.',
#                            'City': 'Information not available',
#                            'Country': 'Information not available',
#                            'Industry': 'Information not available',
#                            'Name': 'ETRACS Monthly Pay 2xLeveraged US High '
#                                    'Dividend Low Volatility ETN',
#                            'Sector': 'Information not available',
#                            'State': 'Information not available',
#                            'Ticker': 'HDLB',
#                            'text': 'The index is designed to measure the '
#                                    'performance of 40 dividend yielding, '
#                                    'relatively lower volatility Index '
#                                    'Constituent Securities from the universe '
#                                    'of the largest 1,000 U.S. listed stocks by '
#                                    'market capitalization, as described '
#                                    'herein. The Securities seek to approximate '
#                                    'the monthly returns that might be '
#                                    'available to investors through a leveraged '
#                                    '“long” investment in the index constituent '
#                                    'securities.'},
#               'score': 0.385751694,
#               'values': []},
#              {'id': 'KKR',
#               'metadata': {'Business Summary': 'KKR & Co. Inc. is a private '
#                                                'equity and real estate '
#                                                'investment firm specializing '
#                                                'in direct and fund of fund '
#                                                'investments. It specializes in '
#                                                'acquisitions, leveraged '
#                                                'buyouts, management buyouts, '
#                                                'credit special situations, '
#                                                'growth equity, mature, '
#                                                'mezzanine, distressed, '
#                                                'turnaround, lower middle '
#                                                'market, and middle market '
#                                                'investments. The firm '
#                                                'considers investments in all '
#                                                'industries with a focus on '
#                                                'software, security, '
#                                                'semiconductors, consumer '
#                                                'electronics, internet of '
#                                                'things (iot), internet, '
#                                                'information services, '
#                                                'information technology '
#                                                'infrastructure, financial '
#                                                'technology, network and cyber '
#                                                'security architecture, '
#                                                'engineering and operations, '
#                                                'content, technology and '
#                                                'hardware, energy and '
#                                                'infrastructure, real estate, '
#                                                'services industry with a focus '
#                                                'on business services, '
#                                                'intelligence, industry-leading '
#                                                'franchises and companies in '
#                                                'natural resource, containers '
#                                                'and packaging, agriculture, '
#                                                'airports, ports, forestry, '
#                                                'electric utilities, textiles, '
#                                                'apparel and luxury goods, '
#                                                'household durables, digital '
#                                                'media, insurance, brokerage '
#                                                'houses, non-durable goods '
#                                                'distribution, supermarket '
#                                                'retailing, grocery stores, '
#                                                'food, beverage, and tobacco, '
#                                                'hospitals, entertainment '
#                                                'venues and production '
#                                                'companies, publishing, '
#                                                'printing services, capital '
#                                                'goods, financial services, '
#                                                'specialized finance, '
#                                                'pipelines, and renewable '
#                                                'energy. In energy and '
#                                                'infrastructure, it focuses on '
#                                                'the upstream oil and gas and '
#                                                'equipment, minerals and '
#                                                'royalties and services '
#                                                'verticals. In real estate, the '
#                                                'firm seeks to invest in '
#                                                'private and public real estate '
#                                                'securities including '
#                                                'property-level equity, debt '
#                                                'and special situations '
#                                                'transactions and businesses '
#                                                'with significant real estate '
#                                                'holdings, and oil and natural '
#                                                'gas properties. The firm also '
#                                                'invests in asset services '
#                                                'sector that encompasses a '
#                                                'broad array of B2B, B2C and '
#                                                'B2G services verticals '
#                                                'including asset-based, '
#                                                'transport, logistics, '
#                                                'leisure/hospitality, resource '
#                                                'and utility support, '
#                                                'infra-like, mission-critical, '
#                                                'and environmental services. '
#                                                'Within Americas, the firm '
#                                                'prefers to invest in consumer '
#                                                'products; chemicals, metals '
#                                                'and mining; energy and natural '
#                                                'resources; financial services; '
#                                                'healthcare; industrials; media '
#                                                'and communications; retail; '
#                                                'and technology. Within Europe, '
#                                                'the firm invests in consumer '
#                                                'and retail; energy; financial '
#                                                'services; health care; '
#                                                'industrials and chemicals; '
#                                                'media and digital; and telecom '
#                                                'and technologies. Within Asia, '
#                                                'it invests in consumer '
#                                                'products; energy and '
#                                                'resources; financial services; '
#                                                'healthcare; industrials; '
#                                                'logistics; media and telecom; '
#                                                'retail; real estate; and '
#                                                'technology. It also seeks to '
#                                                'make impact investments '
#                                                'focused on identifying and '
#                                                'investing behind businesses '
#                                                'with positive social or '
#                                                'environmental impact. The firm '
#                                                'seeks to invest in mid to '
#                                                'high-end residential '
#                                                'developments but can invest in '
#                                                'other projects throughout '
#                                                'Mainland China through '
#                                                'outright ownership, joint '
#                                                'ventures, and merger. It '
#                                                'invests globally with a focus '
#                                                'on Australia, emerging and '
#                                                'developed Asia, Middle East '
#                                                'and Africa, Nordic, Southeast '
#                                                'Asia, Asia Pacific, Ireland, '
#                                                'Hong Kong, Japan, Taiwan, '
#                                                'India, Vietnam, Malaysia, '
#                                                'Singapore, Indonesia, France, '
#                                                'Germany, Netherlands, United '
#                                                'Kingdom, Caribbean, Mexico, '
#                                                'South America, North America, '
#                                                'Brazil, Latin America, Korea '
#                                                'with a focus on South Korea, '
#                                                'and United States of America. '
#                                                'In the United States and '
#                                                'Europe, the firm focuses on '
#                                                'buyouts of large, publicly '
#                                                'traded companies. For middle '
#                                                'market it seeks to invest in '
#                                                'companies with enterprise '
#                                                'values between $200 million to '
#                                                '$1000 million. The firm '
#                                                'prefers to invest in a range '
#                                                'of debt and public equity '
#                                                'investing and may co-invest. '
#                                                'It seeks a board seat in its '
#                                                'portfolio companies and a '
#                                                'controlling ownership of a '
#                                                'company or a strategic '
#                                                'minority position. The firm '
#                                                'may acquire majority and '
#                                                'minority equity interests, '
#                                                'particularly when making '
#                                                'private equity investments in '
#                                                'Asia or sponsoring investments '
#                                                'as part of a large investor '
#                                                'consortium. The firm typically '
#                                                'holds its investment for a '
#                                                'period of five to seven years '
#                                                'and more and exits through '
#                                                'initial public offerings, '
#                                                'secondary offerings, and sales '
#                                                'to strategic buyers. KKR & Co. '
#                                                'Inc. was founded in 1976 and '
#                                                'is based in New York, New York '
#                                                'with additional offices across '
#                                                'North America, Europe, '
#                                                'Australia and Asia.',
#                            'City': 'New York',
#                            'Country': 'United States',
#                            'Industry': 'Asset Management',
#                            'Name': 'KKR & Co. Inc.',
#                            'Sector': 'Financial Services',
#                            'State': 'NY',
#                            'Ticker': 'KKR',
#                            'text': 'KKR & Co. Inc. is a private equity and '
#                                    'real estate investment firm specializing '
#                                    'in direct and fund of fund investments. It '
#                                    'specializes in acquisitions, leveraged '
#                                    'buyouts, management buyouts, credit '
#                                    'special situations, growth equity, mature, '
#                                    'mezzanine, distressed, turnaround, lower '
#                                    'middle market, and middle market '
#                                    'investments. The firm considers '
#                                    'investments in all industries with a focus '
#                                    'on software, security, semiconductors, '
#                                    'consumer electronics, internet of things '
#                                    '(iot), internet, information services, '
#                                    'information technology infrastructure, '
#                                    'financial technology, network and cyber '
#                                    'security architecture, engineering and '
#                                    'operations, content, technology and '
#                                    'hardware, energy and infrastructure, real '
#                                    'estate, services industry with a focus on '
#                                    'business services, intelligence, '
#                                    'industry-leading franchises and companies '
#                                    'in natural resource, containers and '
#                                    'packaging, agriculture, airports, ports, '
#                                    'forestry, electric utilities, textiles, '
#                                    'apparel and luxury goods, household '
#                                    'durables, digital media, insurance, '
#                                    'brokerage houses, non-durable goods '
#                                    'distribution, supermarket retailing, '
#                                    'grocery stores, food, beverage, and '
#                                    'tobacco, hospitals, entertainment venues '
#                                    'and production companies, publishing, '
#                                    'printing services, capital goods, '
#                                    'financial services, specialized finance, '
#                                    'pipelines, and renewable energy. In energy '
#                                    'and infrastructure, it focuses on the '
#                                    'upstream oil and gas and equipment, '
#                                    'minerals and royalties and services '
#                                    'verticals. In real estate, the firm seeks '
#                                    'to invest in private and public real '
#                                    'estate securities including property-level '
#                                    'equity, debt and special situations '
#                                    'transactions and businesses with '
#                                    'significant real estate holdings, and oil '
#                                    'and natural gas properties. The firm also '
#                                    'invests in asset services sector that '
#                                    'encompasses a broad array of B2B, B2C and '
#                                    'B2G services verticals including '
#                                    'asset-based, transport, logistics, '
#                                    'leisure/hospitality, resource and utility '
#                                    'support, infra-like, mission-critical, and '
#                                    'environmental services. Within Americas, '
#                                    'the firm prefers to invest in consumer '
#                                    'products; chemicals, metals and mining; '
#                                    'energy and natural resources; financial '
#                                    'services; healthcare; industrials; media '
#                                    'and communications; retail; and '
#                                    'technology. Within Europe, the firm '
#                                    'invests in consumer and retail; energy; '
#                                    'financial services; health care; '
#                                    'industrials and chemicals; media and '
#                                    'digital; and telecom and technologies. '
#                                    'Within Asia, it invests in consumer '
#                                    'products; energy and resources; financial '
#                                    'services; healthcare; industrials; '
#                                    'logistics; media and telecom; retail; real '
#                                    'estate; and technology. It also seeks to '
#                                    'make impact investments focused on '
#                                    'identifying and investing behind '
#                                    'businesses with positive social or '
#                                    'environmental impact. The firm seeks to '
#                                    'invest in mid to high-end residential '
#                                    'developments but can invest in other '
#                                    'projects throughout Mainland China through '
#                                    'outright ownership, joint ventures, and '
#                                    'merger. It invests globally with a focus '
#                                    'on Australia, emerging and developed Asia, '
#                                    'Middle East and Africa, Nordic, Southeast '
#                                    'Asia, Asia Pacific, Ireland, Hong Kong, '
#                                    'Japan, Taiwan, India, Vietnam, Malaysia, '
#                                    'Singapore, Indonesia, France, Germany, '
#                                    'Netherlands, United Kingdom, Caribbean, '
#                                    'Mexico, South America, North America, '
#                                    'Brazil, Latin America, Korea with a focus '
#                                    'on South Korea, and United States of '
#                                    'America. In the United States and Europe, '
#                                    'the firm focuses on buyouts of large, '
#                                    'publicly traded companies. For middle '
#                                    'market it seeks to invest in companies '
#                                    'with enterprise values between $200 '
#                                    'million to $1000 million. The firm prefers '
#                                    'to invest in a range of debt and public '
#                                    'equity investing and may co-invest. It '
#                                    'seeks a board seat in its portfolio '
#                                    'companies and a controlling ownership of a '
#                                    'company or a strategic minority position. '
#                                    'The firm may acquire majority and minority '
#                                    'equity interests, particularly when making '
#                                    'private equity investments in Asia or '
#                                    'sponsoring investments as part of a large '
#                                    'investor consortium. The firm typically '
#                                    'holds its investment for a period of five '
#                                    'to seven years and more and exits through '
#                                    'initial public offerings, secondary '
#                                    'offerings, and sales to strategic buyers. '
#                                    'KKR & Co. Inc. was founded in 1976 and is '
#                                    'based in New York, New York with '
#                                    'additional offices across North America, '
#                                    'Europe, Australia and Asia.'},
#               'score': 0.382290602,
#               'values': []},
#              {'id': 'SCHW-PJ',
#               'metadata': {'Business Summary': 'The Charles Schwab '
#                                                'Corporation, together with its '
#                                                'subsidiaries, operates as a '
#                                                'savings and loan holding '
#                                                'company that provides wealth '
#                                                'management, securities '
#                                                'brokerage, banking, asset '
#                                                'management, custody, and '
#                                                'financial advisory services in '
#                                                'the United States and '
#                                                'internationally. The company '
#                                                'operates in two segments, '
#                                                'Investor Services and Advisor '
#                                                'Services. It offers brokerage '
#                                                'accounts with equity and fixed '
#                                                'income trading, margin '
#                                                'lending, options trading, '
#                                                'futures and forex trading, and '
#                                                'cash management capabilities, '
#                                                'including certificates of '
#                                                'deposit; third-party mutual '
#                                                'funds through the Mutual Fund '
#                                                'Marketplace and Mutual Fund '
#                                                'OneSource service, as well as '
#                                                'mutual fund trading and '
#                                                'clearing services to '
#                                                'broker-dealers; '
#                                                'exchange-traded funds; '
#                                                'advisory solutions for managed '
#                                                'portfolios, separately managed '
#                                                'accounts, customized personal '
#                                                'advice for tailored '
#                                                'portfolios, specialized '
#                                                'planning, and full-time '
#                                                'portfolio management; banking '
#                                                'products comprising checking '
#                                                'and savings accounts, first '
#                                                'lien residential real estate '
#                                                'mortgage loans, home equity '
#                                                'lines of credit, and pledged '
#                                                'asset lines; and trust custody '
#                                                'services, personal trust '
#                                                'reporting services, and '
#                                                'administrative trustee '
#                                                'services. It also provides '
#                                                'digital retirement '
#                                                'calculators; integrated web-, '
#                                                'mobile-, and software-based '
#                                                'trading platforms, real-time '
#                                                'market data, options trading, '
# ...
#                                    'clearing services; and advisor services, '
#                                    'including interactive tools and '
#                                    'educational content. The Company operates '
#                                    'through branch offices. The Charles Schwab '
#                                    'Corporation was founded in 1971 and is '
#                                    'headquartered in Westlake, Texas.'},
#               'score': 0.361344725,
#               'values': []},
#              {'id': 'SCHW-PD',
#               'metadata': {'Business Summary': 'The Charles Schwab '
#                                                'Corporation, together with its '
#                                                'subsidiaries, operates as a '
#                                                'savings and loan holding '
#                                                'company that provides wealth '
#                                                'management, securities '
#                                                'brokerage, banking, asset '
#                                                'management, custody, and '
#                                                'financial advisory services in '
#                                                'the United States and '
#                                                'internationally. The company '
#                                                'operates in two segments, '
#                                                'Investor Services and Advisor '
#                                                'Services. It offers brokerage '
#                                                'accounts with equity and fixed '
#                                                'income trading, margin '
#                                                'lending, options trading, '
#                                                'futures and forex trading, and '
#                                                'cash management capabilities, '
#                                                'including certificates of '
#                                                'deposit; third-party mutual '
#                                                'funds through the Mutual Fund '
#                                                'Marketplace and Mutual Fund '
#                                                'OneSource service, as well as '
#                                                'mutual fund trading and '
#                                                'clearing services to '
#                                                'broker-dealers; '
#                                                'exchange-traded funds; '
#                                                'advisory solutions for managed '
#                                                'portfolios, separately managed '
#                                                'accounts, customized personal '
#                                                'advice for tailored '
#                                                'portfolios, specialized '
#                                                'planning, and full-time '
#                                                'portfolio management; banking '
#                                                'products comprising checking '
#                                                'and savings accounts, first '
#                                                'lien residential real estate '
#                                                'mortgage loans, home equity '
#                                                'lines of credit, and pledged '
#                                                'asset lines; and trust custody '
#                                                'services, personal trust '
#                                                'reporting services, and '
#                                                'administrative trustee '
#                                                'services. It also provides '
#                                                'digital retirement '
#                                                'calculators; integrated web-, '
#                                                'mobile-, and software-based '
#                                                'trading platforms, real-time '
#                                                'market data, options trading, '
#                                                'premium research, and '
#                                                'multi-channel access; '
#                                                'self-service education and '
#                                                'support tools; online research '
#                                                'and analysis tools; equity '
#                                                'compensation plan sponsors '
#                                                'full-service recordkeeping for '
#                                                'stock plans, stock options, '
#                                                'restricted stock, performance '
#                                                'shares, and stock appreciation '
#                                                'rights; retirement plan '
#                                                'services; mutual fund clearing '
#                                                'services; and advisor '
#                                                'services, including '
#                                                'interactive tools and '
#                                                'educational content. The '
#                                                'Company operates through '
#                                                'branch offices. The Charles '
#                                                'Schwab Corporation was founded '
#                                                'in 1971 and is headquartered '
#                                                'in Westlake, Texas.',
#                            'City': 'Westlake',
#                            'Country': 'United States',
#                            'Industry': 'Capital Markets',
#                            'Name': 'The Charles Schwab Corporation',
#                            'Sector': 'Financial Services',
#                            'State': 'TX',
#                            'Ticker': 'SCHW-PD',
#                            'text': 'The Charles Schwab Corporation, together '
#                                    'with its subsidiaries, operates as a '
#                                    'savings and loan holding company that '
#                                    'provides wealth management, securities '
#                                    'brokerage, banking, asset management, '
#                                    'custody, and financial advisory services '
#                                    'in the United States and internationally. '
#                                    'The company operates in two segments, '
#                                    'Investor Services and Advisor Services. It '
#                                    'offers brokerage accounts with equity and '
#                                    'fixed income trading, margin lending, '
#                                    'options trading, futures and forex '
#                                    'trading, and cash management capabilities, '
#                                    'including certificates of deposit; '
#                                    'third-party mutual funds through the '
#                                    'Mutual Fund Marketplace and Mutual Fund '
#                                    'OneSource service, as well as mutual fund '
#                                    'trading and clearing services to '
#                                    'broker-dealers; exchange-traded funds; '
#                                    'advisory solutions for managed portfolios, '
#                                    'separately managed accounts, customized '
#                                    'personal advice for tailored portfolios, '
#                                    'specialized planning, and full-time '
#                                    'portfolio management; banking products '
#                                    'comprising checking and savings accounts, '
#                                    'first lien residential real estate '
#                                    'mortgage loans, home equity lines of '
#                                    'credit, and pledged asset lines; and trust '
#                                    'custody services, personal trust reporting '
#                                    'services, and administrative trustee '
#                                    'services. It also provides digital '
#                                    'retirement calculators; integrated web-, '
#                                    'mobile-, and software-based trading '
#                                    'platforms, real-time market data, options '
#                                    'trading, premium research, and '
#                                    'multi-channel access; self-service '
#                                    'education and support tools; online '
#                                    'research and analysis tools; equity '
#                                    'compensation plan sponsors full-service '
#                                    'recordkeeping for stock plans, stock '
#                                    'options, restricted stock, performance '
#                                    'shares, and stock appreciation rights; '
#                                    'retirement plan services; mutual fund '
#                                    'clearing services; and advisor services, '
#                                    'including interactive tools and '
#                                    'educational content. The Company operates '
#                                    'through branch offices. The Charles Schwab '
#                                    'Corporation was founded in 1971 and is '
#                                    'headquartered in Westlake, Texas.'},
#               'score': 0.361344725,
#               'values': []},
#              {'id': 'HQL',
#               'metadata': {'Business Summary': 'Abrdn Life Sciences Investors '
#                                                'is a closed-ended equity '
#                                                'mutual fund launched and '
#                                                'managed by abrdn Inc. The fund '
#                                                'invests in public equity '
#                                                'markets across the globe. It '
#                                                'seeks to invest in stocks of '
#                                                'companies operating in the '
#                                                'life sciences sector, '
#                                                'including the biotechnology, '
#                                                'pharmaceutical, diagnostics, '
#                                                'managed healthcare, medical '
#                                                'equipment, hospitals, '
#                                                'healthcare information '
#                                                'technology and services, '
#                                                'devices and supplies '
#                                                'industries, and in agriculture '
#                                                'and environmental management '
#                                                'industries. The fund primarily '
#                                                'invests in growth stocks of '
#                                                'small cap companies. It '
#                                                'employs fundamental analysis '
#                                                'with a focus on factors such '
#                                                'as market position for '
#                                                'services or products, '
#                                                'experience of business '
#                                                'management, technological '
#                                                'expertise, and the ability '
#                                                'either to generate funds '
#                                                'internally to finance growth '
#                                                'or to secure outside sources '
#                                                'of capital to create its '
#                                                'portfolio. The fund benchmarks '
#                                                'the performance of its '
#                                                'portfolio against the NASDAQ '
#                                                'Biotech Index and the S&P 500 '
#                                                'Index. Abrdn Life Sciences '
#                                                'Investors was formed on '
#                                                'February 20, 1992 and is '
#                                                'domiciled in the United '
#                                                'States.',
#                            'City': 'Philadelphia',
#                            'Country': 'United States',
#                            'Industry': 'Asset Management',
#                            'Name': 'Abrdn Life Sciences Investors',
#                            'Sector': 'Financial Services',
#                            'State': 'PA',
#                            'Ticker': 'HQL',
#                            'text': 'Abrdn Life Sciences Investors is a '
#                                    'closed-ended equity mutual fund launched '
#                                    'and managed by abrdn Inc. The fund invests '
#                                    'in public equity markets across the globe. '
#                                    'It seeks to invest in stocks of companies '
#                                    'operating in the life sciences sector, '
#                                    'including the biotechnology, '
#                                    'pharmaceutical, diagnostics, managed '
#                                    'healthcare, medical equipment, hospitals, '
#                                    'healthcare information technology and '
#                                    'services, devices and supplies industries, '
#                                    'and in agriculture and environmental '
#                                    'management industries. The fund primarily '
#                                    'invests in growth stocks of small cap '
#                                    'companies. It employs fundamental analysis '
#                                    'with a focus on factors such as market '
#                                    'position for services or products, '
#                                    'experience of business management, '
#                                    'technological expertise, and the ability '
#                                    'either to generate funds internally to '
#                                    'finance growth or to secure outside '
#                                    'sources of capital to create its '
#                                    'portfolio. The fund benchmarks the '
#                                    'performance of its portfolio against the '
#                                    'NASDAQ Biotech Index and the S&P 500 '
#                                    'Index. Abrdn Life Sciences Investors was '
#                                    'formed on February 20, 1992 and is '
#                                    'domiciled in the United States.'},
#               'score': 0.360037655,
#               'values': []}],
#  'namespace': 'stock-descriptions',
#  'usage': {'read_units': 6}}

# %%
contexts = [item['metadata']['text'] for item in top_matches['matches']]

# %%
augmented_query = "<CONTEXT>\n" + "\n\n-------\n\n".join(contexts[ : 10]) + "\n-------\n</CONTEXT>\n\n\n\nMY QUESTION:\n" + query

# %%
print(augmented_query)
# Out:
# <CONTEXT>
# Honeywell International Inc. engages in the aerospace technologies, building automation, energy and sustainable solutions, and industrial automation businesses in the United States, Europe, and internationally. The company's Aerospace segment offers auxiliary power units, propulsion engines, integrated avionics, environmental control and electric power systems, engine controls, flight safety, communications, navigation hardware, data and software applications, radar and surveillance systems, aircraft lighting, advanced systems and instruments, satellite and space components, and aircraft wheels and brakes; spare parts; repair, overhaul, and maintenance services; and thermal systems, as well as wireless connectivity services. Its Honeywell Building Technologies segment provides software applications for building control and optimization; sensors, switches, control systems, and instruments for energy management; access control; video surveillance; fire products; and installation, maintenance, and upgrades of systems. The company's Performance Materials and Technologies segment offers automation control, instrumentation, and software and related services; catalysts and adsorbents, equipment, and consulting; and materials to manufacture end products, such as bullet-resistant armor, nylon, computer chips, and pharmaceutical packaging, as well as provides materials based on hydrofluoro-olefin technology. Its Safety and Productivity Solutions segment provides personal protective equipment, apparel, gear, and footwear; gas detection technology; custom-engineered sensors, switches, and controls for sensing and productivity solution; cloud-based notification and emergency messaging; mobile devices and software; custom-engineered sensors, switches, and controls; and data and asset management productivity solutions. Honeywell International Inc. was founded in 1885 and is headquartered in Charlotte, North Carolina.
#
# -------
#
# Applied Materials, Inc. engages in the provision of manufacturing equipment, services, and software to the semiconductor, display, and related industries. The company operates through three segments: Semiconductor Systems, Applied Global Services, and Display and Adjacent Markets. The Semiconductor Systems segment develops, manufactures, and sells various manufacturing equipment that is used to fabricate semiconductor chips or integrated circuits. This segment also offers various technologies, including epitaxy, ion implantation, oxidation/nitridation, rapid thermal processing, physical vapor deposition, chemical vapor deposition, chemical mechanical planarization, electrochemical deposition, atomic layer deposition, etching, and selective deposition and removal, as well as metrology and inspection tools. The Applied Global Services segment provides integrated solutions to optimize equipment and fab performance and productivity comprising spares, upgrades, services, remanufactured earlier generation equipment, and factory automation software for semiconductor, display, and other products. The Display and Adjacent Markets segment offers products for manufacturing liquid crystal displays; organic light-emitting diodes; and other display technologies for TVs, monitors, laptops, personal computers, electronic tablets, smart phones, and other consumer-oriented devices. It operates in the United States, China, Korea, Taiwan, Japan, Southeast Asia, and Europe. The company was incorporated in 1967 and is headquartered in Santa Clara, California.
#
# -------
#
# Advanced Micro Devices, Inc. operates as a semiconductor company worldwide. It operates through Data Center, Client, Gaming, and Embedded segments. The company offers x86 microprocessors and graphics processing units (GPUs) as an accelerated processing unit, chipsets, data center, and professional GPUs; and embedded processors, and semi-custom system-on-chip (SoC) products, microprocessor and SoC development services and technology, data processing unites, field programmable gate arrays (FPGA), and adaptive SoC products. It provides processors under the AMD Ryzen, AMD Ryzen PRO, Ryzen Threadripper, Ryzen Threadripper PRO, AMD Athlon, AMD Athlon PRO, and AMD PRO A-Series brand names; graphics under the AMD Radeon graphics and AMD Embedded Radeon graphics; and professional graphics under the AMD Radeon Pro graphics brand name. In addition, the company offers data center graphics under the Radeon Instinct and Radeon PRO V-series brands, as well as servers under the AMD Instinct accelerators brand; server microprocessors under the AMD EPYC brands; low power solutions under the AMD Athlon, AMD Geode, AMD Ryzen, AMD EPYC, AMD R-Series, and G-Series brands; FPGA products under the Virtex-6, Virtex-7, Virtex UltraScale+, Kintex-7, Kintex UltraScale, Kintex UltraScale+, Artix-7, Artix UltraScale+, Spartan-6, and Spartan-7 brands; adaptive SOCs under the Zynq-7000, Zynq UltraScale+ MPSoC, Zynq UltraScale+ RFSoCs, Versal HBM, Versal Premium, Versal Prime, Versal AI Core, Versal AI Edge, Vitis, and Vivado brands; and compute and network acceleration board products under the Alveo brand. It serves original equipment and design manufacturers, public cloud service providers, system integrators, independent distributors, and add-in-board manufacturers through its direct sales force, and sales representatives. Advanced Micro Devices, Inc. was incorporated in 1969 and is headquartered in Santa Clara, California.
#
# -------
#
# Broadcom Inc. designs, develops, and supplies various semiconductor devices with a focus on complex digital and mixed signal complementary metal oxide semiconductor based devices and analog III-V based products worldwide. The company operates in two segments, Semiconductor Solutions and Infrastructure Software. It provides set-top box system-on-chips (SoCs); cable, digital subscriber line, and passive optical networking central office/consumer premise equipment SoCs; wireless local area network access point SoCs; Ethernet switching and routing custom silicon solutions; serializer/deserializer application specific integrated circuits; optical and copper, and physical layer devices; and fiber optic components and RF semiconductor devices. The company also offers RF front end modules and filter; Wi-Fi, Bluetooth, and global positioning system/global navigation satellite system SoCs; custom touch controllers; inductive charging; attached small computer system interface, and redundant array of independent disks controllers and adapters; peripheral component interconnect express; fiber channel host bus adapters; read channel based SoCs; custom flash controllers; preamplifiers; optocouplers, industrial fiber optics, and motion control encoders and subsystems; light emitting diode, ethernet PHYs, switch ICs, and camera microcontrollers. Its products are used in various applications, including enterprise and data center networking, home connectivity, set-top boxes, broadband access, telecommunication equipment, smartphones and base stations, data center servers and storage systems, factory automation, power generation and alternative energy systems, and electronic displays. Broadcom Inc. was founded in 1961 and is headquartered in Palo Alto, California.
#
# -------
#
# Texas Instruments Incorporated designs, manufactures, and sells semiconductors to electronics designers and manufacturers in the United States and internationally. The company operates through Analog and Embedded Processing segments. The Analog segment offers power products to manage power requirements across various voltage levels, including battery-management solutions, DC/DC switching regulators, AC/DC and isolated controllers and converters, power switches, linear regulators, voltage references, and lighting products. This segment provides signal chain products that sense, condition, and measure signals to allow information to be transferred or converted for further processing and control, including amplifiers, data converters, interface products, motor drives, clocks, and logic and sensing products. The Embedded Processing segment offers microcontrollers that are used in electronic equipment; digital signal processors for mathematical computations; and applications processors for specific computing activity. This segment offers products for use in various markets, such as industrial, automotive, personal electronics, communications equipment, enterprise systems, and calculators and other. It provides DLP products primarily for use in project high-definition images; calculators; and application-specific integrated circuits. The company markets and sells its semiconductor products through direct sales and distributors, as well as through its website. Texas Instruments Incorporated was founded in 1930 and is headquartered in Dallas, Texas.
#
# -------
#
# Stryker Corporation operates as a medical technology company. The company operates through two segments, MedSurg and Neurotechnology, and Orthopaedics and Spine. The Orthopaedics and Spine segment provides implants for use in total joint replacements, such as hip, knee and shoulder, and trauma and extremities surgeries. This segment also offers spinal implant products comprising cervical and thoracolumbar systems that include fixation, minimally invasive and interbody systems used in spinal injury, complex spine and degenerative therapies. The MedSurg and Neurotechnology segment offers surgical equipment, and surgical navigation systems, endoscopic and communications systems, patient handling, emergency medical equipment and intensive care disposable products, reprocessed and remanufactured medical devices, clinical communication and workflow solutions, and other medical device products that are used in various medical specialties, as well as patient and caregiver safety technologies. This segment also provides neurosurgical, neurovascular and craniomaxillofacial implant products, which include products used for minimally invasive endovascular procedures; products for brain and open skull based surgical procedures; orthobiologic and biosurgery products, such as synthetic bone grafts and vertebral augmentation products; minimally invasive products for the treatment of acute ischemic and hemorrhagic stroke; and craniomaxillofacial implant products, including cranial, maxillofacial, and chest wall devices, as well as dural substitutes and sealants. The company sells its products to doctors, hospitals, and other healthcare facilities through company-owned subsidiaries and branches, as well as third-party dealers and distributors in approximately 75 countries. Stryker Corporation was founded in 1941 and is headquartered in Portage, Michigan.
#
# -------
#
# Walmart Inc. engages in the operation of retail, wholesale, other units, and eCommerce worldwide. The company operates through three segments: Walmart U.S., Walmart International, and Sam's Club. It operates supercenters, supermarkets, hypermarkets, warehouse clubs, cash and carry stores, and discount stores under Walmart and Walmart Neighborhood Market brands; membership-only warehouse clubs; ecommerce websites, such as walmart.com.mx, walmart.ca, flipkart.com, PhonePe and other sites; and mobile commerce applications. The company offers grocery and consumables, including dairy, meat, bakery, deli, produce, dry, chilled or frozen packaged foods, alcoholic and nonalcoholic beverages, floral, snack foods, candy, other grocery items, health and beauty aids, paper goods, laundry and home care, baby care, pet supplies, and other consumable items; fuel, tobacco and other categories. It is also involved in the provision of health and wellness products covering pharmacy, optical and hearing services, and over-the-counter drugs and other medical products; and home and apparel including home improvement, outdoor living, gardening, furniture, apparel, jewelry, tools and power equipment, housewares, toys, seasonal items, mattresses and tire and battery centers. In addition, the company offers consumer electronics and accessories, software, video games, office supplies, appliances, and third-party gift cards. Further, it operates digital payment platforms; and offers financial services and related products, including money transfers, bill payments, money orders, check cashing, prepaid access, co-branded credit cards, installment lending, and earned wage access. Additionally, the company markets lines of merchandise under private brands, including Allswell, Athletic Works, Equate, and Free Assembly. The company was formerly known as Wal-Mart Stores, Inc. and changed its name to Walmart Inc. in February 2018. Walmart Inc. was founded in 1945 and is based in Bentonville, Arkansas.
#
# -------
#
# Lowe's Companies, Inc., together with its subsidiaries, operates as a home improvement retailer in the United States. The company offers a line of products for construction, maintenance, repair, remodeling, and decorating. It also provides home improvement products, such as appliances, seasonal and outdoor living, lawn and garden, lumber, kitchens and bath, tools, paint, millwork, hardware, flooring, rough plumbing, building materials, décor, and electrical. In addition, the company offers installation services through independent contractors in various product categories; and extended protection plans and repair services. It sells its national brand-name merchandise and private brand products to professional customers, homeowners, renters, businesses, and government. The company also sells its products through Lowes.com website; and through mobile applications. Lowe's Companies, Inc. was founded in 1921 and is based in Mooresville, North Carolina.
#
# -------
#
# Caterpillar Inc. manufactures and sells construction and mining equipment, off-highway diesel and natural gas engines, industrial gas turbines, and diesel-electric locomotives in worldwide. Its Construction Industries segment offers asphalt pavers, compactors, road reclaimers, forestry machines, cold planers, material handlers, track-type tractors, excavators, telehandlers, motor graders, and pipelayers; compact track, wheel, track-type, backhoe, and skid steer loaders; and related parts and tools. The company's Resource Industries segment provides electric rope and hydraulic shovels, draglines, rotary drills, hard rock vehicles, tractors, mining trucks, wheel loaders, off-highway and articulated trucks, wheel tractor scrapers and dozers, fleet management products, landfill and soil compactors, machinery components, autonomous ready vehicles and solutions, work tools, and safety services and mining performance solutions, as well as related parts and services. Its Energy & Transportation segment offers reciprocating engine powered generator sets; reciprocating engines, drivetrain, and integrated systems and solutions; turbines, centrifugal gas compressors, and related services; and diesel-electric locomotives and components, and other rail-related products. The company's Financial Products segment provides operating and finance leases, installment sale contracts, revolving charge accounts, repair/rebuild financing services, working capital loans, and wholesale financing; and insurance and risk management products and services. Its All Other Operating segment offers filters and fluids, undercarriage, ground engaging tools, fluid transfer products, precision seals, and rubber sealing and connecting components; parts distribution; logistics solutions and distribution services; brand management and marketing strategy services; and digital investments services. Caterpillar Inc. was founded in 1925 and is headquartered in Irving, Texas.
#
# -------
#
# NVIDIA Corporation provides graphics and compute and networking solutions in the United States, Taiwan, China, Hong Kong, and internationally. The Graphics segment offers GeForce GPUs for gaming and PCs, the GeForce NOW game streaming service and related infrastructure, and solutions for gaming platforms; Quadro/NVIDIA RTX GPUs for enterprise workstation graphics; virtual GPU or vGPU software for cloud-based visual and virtual computing; automotive platforms for infotainment systems; and Omniverse software for building and operating metaverse and 3D internet applications. The Compute & Networking segment comprises Data Center computing platforms and end-to-end networking platforms, including Quantum for InfiniBand and Spectrum for Ethernet; NVIDIA DRIVE automated-driving platform and automotive development agreements; Jetson robotics and other embedded platforms; NVIDIA AI Enterprise and other software; and DGX Cloud software and services. The company's products are used in gaming, professional visualization, data center, and automotive markets. It sells its products to original equipment manufacturers, original device manufacturers, system integrators and distributors, independent software vendors, cloud service providers, consumer internet companies, add-in board manufacturers, distributors, automotive manufacturers and tier-1 automotive suppliers, and other ecosystem participants. NVIDIA Corporation was incorporated in 1993 and is headquartered in Santa Clara, California.
# -------
# </CONTEXT>
#
#
#
# MY QUESTION:
# What are some companies that manufacture consumer hardware?

# %% [markdown]
# # Setting up Groq for RAG
#
# 1. Get your Groq API Key [here](https://console.groq.com/keys). Through Groq, you get free access to various LLMs
#
# 2. Paste your Groq API Key into your Google Colab secrets, and make sure to enable permissions for it
#
# ![Screenshot 2024-11-25 at 12 00 16 AM](https://github.com/user-attachments/assets/e5525d29-bca6-4dbd-892b-cc770a6b281d)

# %%
client = OpenAI(
  base_url="https://api.groq.com/openai/v1",
  api_key=userdata.get("GROQ_API_KEY")
)

# %%
system_prompt = f"""You are an expert at providing answers about stocks. Please answer my question provided.
"""

llm_response = client.chat.completions.create(
    model="llama-3.1-70b-versatile",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": augmented_query}
    ]
)

response = llm_response.choices[0].message.content

# %%
print(response)
# Out:
# Based on the context provided, some companies that manufacture consumer hardware include:
#
# 1. Advanced Micro Devices, Inc. (AMD): They manufacture x86 microprocessors and graphics processing units (GPUs) for consumer PCs and laptops, as well as embedded processors for various applications.
# 2. NVIDIA Corporation: They manufacture graphics processing units (GPUs) for gaming PCs, laptops, and mobile devices, as well as specialized hardware for professional workflows and data center applications.
# 3. Applied Materials, Inc.: They provide manufacturing equipment and services to the semiconductor industry, which is used to produce consumer hardware devices such as smartphones, laptops, and desktop PCs.
# 4. Texas Instruments Incorporated: They manufacture a wide range of semiconductor products, including microcontrollers, data converters, and power management devices, which are used in various consumer hardware devices such as smartphones, smart home devices, and gaming consoles.
#
# Additionally, some of the companies mentioned in the context are involved in the production of consumer electronics, such as:
#
# 1. Honeywell International Inc.: They provide software and hardware solutions for building automation, HVAC, and security systems.
# 2. Broadcom Inc.: They manufacture semiconductor devices for various consumer electronics applications, including smartphones, smart home devices, and set-top boxes.
# 3. Lowe's Companies, Inc.: They sell a range of consumer electronics and home appliances, including consumer hardware devices.
# 4. Walmart Inc.: They sell a wide range of consumer electronics, including consumer hardware devices such as smartphones, laptops, and gaming consoles.
#
# Note that not all of these companies manufacture consumer hardware directly, but they are involved in the production or sale of consumer electronics and devices.
